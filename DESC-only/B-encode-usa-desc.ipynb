# %%
import pandas as pd
dt = pd.read_csv('subset-LA-even.csv')
# dt = dt[dt.Duration<=720]

# %%
dt
# Out:
#               ID   Source  Severity  Start_Lat   Start_Lng    End_Lat  \
# 0      A-7463401  Source1         3  32.681160  -97.024260  32.676180
# 1      A-3535009  Source1         3  33.848040 -117.871280  33.845270
# 2      A-7197318  Source1         3  40.795880  -73.976500  40.795880
# 3      A-1425448  Source2         3  42.385468  -83.275871        NaN
# 4      A-7067583  Source1         3  41.809790  -87.985610  41.809790
# ...          ...      ...       ...        ...         ...        ...
# 48709  A-7298115  Source1         4  42.512840  -84.655700  42.512840
# 48710  A-3418355  Source1         4  34.494960 -116.945370  34.459400
# 48711  A-4253909  Source1         4  35.759982  -80.990752  35.762291
# 48712  A-7543803  Source1         4  38.761990  -90.424390  38.752880
# 48713  A-4358343  Source1         4  40.205702  -78.713404  40.217212
#
#           End_Lng  Distance(mi)  \
# 0      -97.034830         0.704
# 1     -117.876180         0.340
# 2      -73.976500         0.000
# 3             NaN         0.000
# 4      -87.985610         0.000
# ...           ...           ...
# 48709  -84.655700         0.000
# 48710 -116.945760         2.457
# 48711  -80.985212         0.349
# 48712  -90.438730         0.997
# 48713  -78.748294         2.005
#
#                                              Description  \
# 0                     Ramp to I-20 Westbound - Accident.
# 1                              Ramp to CA-57 - Accident.
# 2                         At 95th St/96th St - Accident.
# 3      Right lane blocked and right hand shoulder blo...
# 4                      At CR-25/Fairview Ave - Accident.
# ...                                                  ...
# 48709  Closed at Knight St - Road closed due to accid...
# 48710  Closed between Granite Rd and Rabbit Springs R...
# 48711          The road is closed near Old Mountain Rd.
# 48712  Closed at MO-180/St Charles Rock/Exit 20 - Roa...
# 48713  Incident on PA-56 WB near SCHOOL ST Road close...
#
#                              Street  ... Sunrise_Sunset Civil_Twilight  \
# 0      President George Bush Tpke S  ...          Night          Night
# 1                           CA-91 W  ...          Night          Night
# 2               Henry Hudson Pkwy N  ...            Day            Day
# 3                      Telegraph Rd  ...          Night          Night
# 4                       W Ogden Ave  ...            Day            Day
# ...                             ...  ...            ...            ...
# 48709                   W Knight St  ...          Night          Night
# 48710                    Barstow Rd  ...            Day            Day
# 48711                     Holman Rd  ...            Day            Day
# 48712                       I-270 S  ...            Day            Day
# 48713                Clear Shade Dr  ...            Day            Day
#
#       Nautical_Twilight Astronomical_Twilight Duration Start_Time_hour  \
# 0                 Night                 Night     30.0              22
# 1                 Night                 Night    360.0               1
# 2                   Day                   Day     30.0               6
# 3                 Night                 Night    116.0               3
# 4                   Day                   Day     30.0              13
# ...                 ...                   ...      ...             ...
# 48709             Night                 Night     29.0              21
# 48710               Day                   Day    360.0              17
# 48711               Day                   Day    240.0              14
# 48712               Day                   Day    360.0              16
# 48713               Day                   Day    245.0               7
#
#        Start_Time_month  Weather_Timestamp_hour  Weather_Timestamp_month  \
# 0                     1                      22                        1
# 1                    11                       0                       11
# 2                     4                       6                        4
# 3                     8                       2                        8
# 4                     6                      12                        6
# ...                 ...                     ...                      ...
# 48709                12                      21                       12
# 48710                 3                      17                        3
# 48711                12                      13                       12
# 48712                 8                      16                        8
# 48713                 3                       7                        3
#
#                                                 FullText
# 0      Accident ID A-7463401, Source Source1, Start L...
# 1      Accident ID A-3535009, Source Source1, Start L...
# 2      Accident ID A-7197318, Source Source1, Start L...
# 3      Accident ID A-1425448, Source Source2, Start L...
# 4      Accident ID A-7067583, Source Source1, Start L...
# ...                                                  ...
# 48709  Accident ID A-7298115, Source Source1, Start L...
# 48710  Accident ID A-3418355, Source Source1, Start L...
# 48711  Accident ID A-4253909, Source Source1, Start L...
# 48712  Accident ID A-7543803, Source Source1, Start L...
# 48713  Accident ID A-4358343, Source Source1, Start L...
#
# [48714 rows x 47 columns]

# %%
dt.fulltext[0]
# Out:
# "Crash_Ref_Number: 356077.0, Crash_Year: 2021.0, Crash_Month: July, Crash_Day_Of_Week: Thursday, Crash_Hour: 10.0, Crash_Nature: Angle, Crash_Type: Multi-Vehicle, Crash_Longitude: 151.577727183662, Crash_Latitude: -27.5272093042477, Crash_Street: Jondaryan - Mt Tyson Rd, Crash_Street_Intersecting: Toowoomba - Cecil Plains Rd, State_Road_Name: Toowoomba - Cecil Plains Road, Loc_Suburb: Mount Tyson, Loc_Local_Government_Area: Toowoomba Region, Loc_Post_Code: 4356, Loc_Police_Division: Jondaryan, Loc_Police_District: Darling Downs, Loc_Police_Region: Southern, Loc_Queensland_Transport_Region: Southern, Loc_Main_Roads_Region: Southern Queensland, Loc_ABS_Statistical_Area_2: Jondaryan, Loc_ABS_Statistical_Area_3: Darling Downs - East, Loc_ABS_Statistical_Area_4: Darling Downs - Maranoa, Loc_ABS_Remoteness: Inner Regional, Loc_State_Electorate: Condamine, Loc_Federal_Electorate: Groom, Crash_Controlling_Authority: State-controlled, Crash_Roadway_Feature: Intersection - Cross, Crash_Traffic_Control: Give way sign, Crash_Speed_Limit: 100 - 110 km/h, Crash_Road_Surface_Condition: Sealed - Dry, Crash_Atmospheric_Condition: Clear, Crash_Lighting_Condition: Daylight, Crash_Road_Horiz_Align: Straight, Crash_Road_Vert_Align: Level, Crash_DCA_Code: 101.0, Crash_DCA_Description: Veh'S Adjacent Approach: Thru-Thru, Crash_DCA_Group_Description: Intersection from adjacent approaches, DCA_Key_Approach_Dir: S, Count_Unit_Car: 1.0, Count_Unit_Motorcycle_Moped: 0.0, Count_Unit_Truck: 1.0, Count_Unit_Bus: 0.0, Count_Unit_Bicycle: 0.0, Count_Unit_Pedestrian: 0.0, Count_Unit_Other: 0.0"

# %%
import transformers
import torch
import numpy as np
from torch import nn
from transformers import AutoTokenizer, AlbertModel
from transformers import AutoTokenizer, DistilBertModel

device = torch.device("cuda:1")

# %%
import transformers
import torch
import numpy as np
from torch import nn
from transformers import AutoTokenizer, AlbertModel
from transformers import AutoTokenizer, DistilBertModel

device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")  # Check if GPU is available
from transformers import AutoTokenizer


def load_model(model_name):
    if model_name.lower() == 'roberta-large':
        model_type = "roberta-large"
        tokenizer = transformers.RobertaTokenizer.from_pretrained(model_type)
        model = transformers.RobertaModel.from_pretrained(model_type)
        
#     elif model_name.lower() == 'mobilebert':
        
#         tokenizer = transformers.AutoTokenizer.from_pretrained("google/mobilebert-uncased")
#         model = transformers.AutoModel.from_pretrained("google/mobilebert-uncased")
    elif model_name.lower() == 'distilroberta':
        model_type = 'distilroberta-base'
        tokenizer = transformers.AutoTokenizer.from_pretrained(model_type)
        model = transformers.AutoModel.from_pretrained(model_type)
        
    elif model_name.lower() == 'bert-cased':
        model_type = 'bert-base-cased'
        tokenizer = transformers.AutoTokenizer.from_pretrained(model_type)
        model = transformers.AutoModel.from_pretrained(model_type)
        
        
    elif model_name.lower() == 'albert':
        model_type = 'albert-base-v2'
        tokenizer = transformers.AutoTokenizer.from_pretrained(model_type)
        model = transformers.AutoModel.from_pretrained(model_type)

    elif model_name.lower() == 'albert-large':
        model_type = 'albert-xxlarge-v2'
        tokenizer = transformers.AutoTokenizer.from_pretrained(model_type)
        model = transformers.AutoModel.from_pretrained(model_type)
        
    elif model_name.lower() == 'bert':
        model_type = 'bert-base-uncased'
        tokenizer = transformers.BertTokenizer.from_pretrained(model_type)
        model = transformers.BertModel.from_pretrained(model_type)
    elif model_name.lower() == 'bert-large':
        model_type = 'bert-large-uncased'
        tokenizer = transformers.BertTokenizer.from_pretrained(model_type)
        model = transformers.BertModel.from_pretrained(model_type)
    elif model_name.lower() == 'gpt2':
        model_type = 'gpt2'
        tokenizer = transformers.GPT2Tokenizer.from_pretrained(model_type)
        model = transformers.GPT2Model.from_pretrained(model_type)
        tokenizer.pad_token = tokenizer.eos_token
        
    elif model_name.lower() == 'gpt2-large':
        model_type = 'gpt2-large'
        tokenizer = transformers.GPT2Tokenizer.from_pretrained(model_type)
        model = transformers.GPT2Model.from_pretrained(model_type)
        tokenizer.pad_token = tokenizer.eos_token
        
    elif model_name.lower() == 'roberta':
        model_type = 'roberta-base'
        tokenizer = transformers.RobertaTokenizer.from_pretrained(model_type)
        model = transformers.RobertaModel.from_pretrained(model_type)
    elif model_name.lower() == 'xlnet':
        model_type = 'xlnet-base-cased'
        tokenizer = transformers.XLNetTokenizer.from_pretrained(model_type)
        model = transformers.XLNetModel.from_pretrained(model_type)
    elif model_name.lower() == 'xlnet-large':
        model_type = 'xlnet-large-cased'
        tokenizer = transformers.XLNetTokenizer.from_pretrained(model_type)
        model = transformers.XLNetModel.from_pretrained(model_type)
#         model.to("cuda")
    elif model_name.lower() == 'mt5':
        model_type = 'google/mt5-base'
        tokenizer = transformers.AutoTokenizer.from_pretrained(model_type,fast=False)
        model = transformers.AutoModel.from_pretrained(model_type)
    elif model_name.lower() == 'mt5-large':
        model_type = 'google/mt5-large'
        tokenizer = transformers.AutoTokenizer.from_pretrained(model_type,fast=False)
        model = transformers.AutoModel.from_pretrained(model_type)
    else:
        raise ValueError("Model name not supported. Choose from ['bert', 'gpt2', 'roberta', 'xlnet', 'bloom']")
    
#     model = nn.DataParallel(model, device_ids=[0, 1])
    model = model.to(device)
    return tokenizer, model
import time

def extract_features(texts, model_name='bert', batch_size=48):
    tokenizer, model = load_model(model_name)
    all_features = []
    time_stats = []  # Array to collect run time statistics

    total_batches = (len(texts) + batch_size - 1) // batch_size

    for i in range(0, len(texts), batch_size):
        start_time = time.time()
        batch_num = i // batch_size + 1
        print(f"Processing batch {batch_num}/{total_batches}")

        batch_texts = texts[i:i+batch_size]
        tokenized_texts = [tokenizer.encode(text, add_special_tokens=True, padding='max_length', max_length=500, truncation=True) for text in batch_texts]

        max_length = max(len(seq) for seq in tokenized_texts)
        padded_sequences = [seq + [0] * (max_length - len(seq)) for seq in tokenized_texts]

        input_ids = torch.tensor(padded_sequences)
        attention_masks = torch.where(input_ids != 0, torch.tensor(1), torch.tensor(0))
        
        IDS = input_ids.to(model.device)
        
        with torch.no_grad():
            if model_name.lower() == 'mt5':
                print('this is mt5')
                input_embeds = model.get_input_embeddings()(IDS)
#                 input_embeds = model.get_input_embeddings()(IDS)
#                 features = model(input_ids=IDS, decoder_inputs_embeds=input_embeds)[0]
                features= model(input_ids=IDS, decoder_input_ids = IDS)[0]
                features = features.mean(dim=1)
                print('obtained features')
            elif model_name.lower() == 'mt5-large':
                features = model(input_ids=IDS, decoder_input_ids=IDS)[0]
                features = features.mean(dim=1)
            else:
                
                features = model(input_ids=IDS, attention_mask=attention_masks.to(model.device))[0][:, 0, :]

        features_np = features.cpu().numpy()
        all_features.append(features_np)

        # Calculate time taken and append to statistics
        elapsed_time = time.time() - start_time
        time_stats.append(elapsed_time)
        print(f"Batch {batch_num}/{total_batches} processed in {elapsed_time:.2f} seconds (time per batch)")

    print("Run time statistics:")
    print(f"Average time per batch: {np.mean(time_stats):.2f} seconds")
    print(f"Total time: {np.sum(time_stats):.2f} seconds")
    
    del model
    torch.cuda.empty_cache()
    
    return np.vstack(all_features), time_stats  # Return time statistics along with features

# %%
# torch.cuda.empty_cache()

# %%
import numpy as np

def extract_and_save_features(texts, model_name):
    # Extract features
    features,times = extract_features(texts, model_name)
    
    print(times)
    
    # Save features to disk
    np.save(f'{model_name}_features.npy', features)

    print(f"Features extracted and saved for model: {model_name}")
    del features

# Define the list of model names
#  ,'mt5','mt5-large'
# model_names = ['bert', 'bert-large','gpt2', 'roberta', 'mt5', 'mt5-large', 'xlnet','xlnet-large']

# model_names = ['bert', 'bert-large','gpt2', 'roberta', 'mt5', 'mt5-large', 'xlnet','xlnet-large']
# model_names = []
model_names = ['distilroberta','bert-cased']#'roberta-large','albert','albert-large']
# model_names = []
# For each model, extract and save features
for model_name in model_names:
    print(model_name)
    extract_and_save_features(dt.Description, model_name)
# Out:
# distilroberta
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Processing batch 1/1015
# Batch 1/1015 processed in 0.32 seconds (time per batch)
# Processing batch 2/1015
# Batch 2/1015 processed in 0.29 seconds (time per batch)
# Processing batch 3/1015
# Batch 3/1015 processed in 0.29 seconds (time per batch)
# Processing batch 4/1015
# Batch 4/1015 processed in 0.29 seconds (time per batch)
# Processing batch 5/1015
# Batch 5/1015 processed in 0.29 seconds (time per batch)
# Processing batch 6/1015
# Batch 6/1015 processed in 0.29 seconds (time per batch)
# Processing batch 7/1015
# Batch 7/1015 processed in 0.29 seconds (time per batch)
# Processing batch 8/1015
# Batch 8/1015 processed in 0.29 seconds (time per batch)
# Processing batch 9/1015
# Batch 9/1015 processed in 0.29 seconds (time per batch)
# Processing batch 10/1015
# Batch 10/1015 processed in 0.29 seconds (time per batch)
# Processing batch 11/1015
# Batch 11/1015 processed in 0.29 seconds (time per batch)
# Processing batch 12/1015
# Batch 12/1015 processed in 0.29 seconds (time per batch)
# Processing batch 13/1015
# Batch 13/1015 processed in 0.29 seconds (time per batch)
# Processing batch 14/1015
# Batch 14/1015 processed in 0.29 seconds (time per batch)
# Processing batch 15/1015
# Batch 15/1015 processed in 0.29 seconds (time per batch)
# Processing batch 16/1015
# Batch 16/1015 processed in 0.29 seconds (time per batch)
# Processing batch 17/1015
# Batch 17/1015 processed in 0.29 seconds (time per batch)
# Processing batch 18/1015
# Batch 18/1015 processed in 0.29 seconds (time per batch)
# Processing batch 19/1015
# Batch 19/1015 processed in 0.29 seconds (time per batch)
# Processing batch 20/1015
# Batch 20/1015 processed in 0.29 seconds (time per batch)
# Processing batch 21/1015
# Batch 21/1015 processed in 0.29 seconds (time per batch)
# Processing batch 22/1015
# Batch 22/1015 processed in 0.29 seconds (time per batch)
# Processing batch 23/1015
# Batch 23/1015 processed in 0.29 seconds (time per batch)
# Processing batch 24/1015
# Batch 24/1015 processed in 0.29 seconds (time per batch)
# Processing batch 25/1015
# Batch 25/1015 processed in 0.29 seconds (time per batch)
# Processing batch 26/1015
# Batch 26/1015 processed in 0.29 seconds (time per batch)
# Processing batch 27/1015
# Batch 27/1015 processed in 0.29 seconds (time per batch)
# Processing batch 28/1015
# Batch 28/1015 processed in 0.29 seconds (time per batch)
# Processing batch 29/1015
# Batch 29/1015 processed in 0.29 seconds (time per batch)
# Processing batch 30/1015
# Batch 30/1015 processed in 0.29 seconds (time per batch)
# Processing batch 31/1015
# Batch 31/1015 processed in 0.29 seconds (time per batch)
# Processing batch 32/1015
# Batch 32/1015 processed in 0.29 seconds (time per batch)
# Processing batch 33/1015
# Batch 33/1015 processed in 0.29 seconds (time per batch)
# Processing batch 34/1015
# Batch 34/1015 processed in 0.29 seconds (time per batch)
# Processing batch 35/1015
# Batch 35/1015 processed in 0.29 seconds (time per batch)
# Processing batch 36/1015
# Batch 36/1015 processed in 0.29 seconds (time per batch)
# Processing batch 37/1015
# Batch 37/1015 processed in 0.29 seconds (time per batch)
# Processing batch 38/1015
# Batch 38/1015 processed in 0.29 seconds (time per batch)
# Processing batch 39/1015
# Batch 39/1015 processed in 0.29 seconds (time per batch)
# Processing batch 40/1015
# Batch 40/1015 processed in 0.29 seconds (time per batch)
# Processing batch 41/1015
# Batch 41/1015 processed in 0.29 seconds (time per batch)
# Processing batch 42/1015
# Batch 42/1015 processed in 0.29 seconds (time per batch)
# Processing batch 43/1015
# Batch 43/1015 processed in 0.29 seconds (time per batch)
# Processing batch 44/1015
# Batch 44/1015 processed in 0.29 seconds (time per batch)
# Processing batch 45/1015
# Batch 45/1015 processed in 0.29 seconds (time per batch)
# Processing batch 46/1015
# Batch 46/1015 processed in 0.29 seconds (time per batch)
# Processing batch 47/1015
# Batch 47/1015 processed in 0.29 seconds (time per batch)
# Processing batch 48/1015
# Batch 48/1015 processed in 0.29 seconds (time per batch)
# Processing batch 49/1015
# Batch 49/1015 processed in 0.29 seconds (time per batch)
# Processing batch 50/1015
# Batch 50/1015 processed in 0.29 seconds (time per batch)
# Processing batch 51/1015
# Batch 51/1015 processed in 0.29 seconds (time per batch)
# Processing batch 52/1015
# Batch 52/1015 processed in 0.29 seconds (time per batch)
# Processing batch 53/1015
# Batch 53/1015 processed in 0.29 seconds (time per batch)
# Processing batch 54/1015
# Batch 54/1015 processed in 0.29 seconds (time per batch)
# Processing batch 55/1015
# Batch 55/1015 processed in 0.29 seconds (time per batch)
# Processing batch 56/1015
# Batch 56/1015 processed in 0.29 seconds (time per batch)
# Processing batch 57/1015
# Batch 57/1015 processed in 0.29 seconds (time per batch)
# Processing batch 58/1015
# Batch 58/1015 processed in 0.29 seconds (time per batch)
# Processing batch 59/1015
# Batch 59/1015 processed in 0.29 seconds (time per batch)
# Processing batch 60/1015
# Batch 60/1015 processed in 0.29 seconds (time per batch)
# Processing batch 61/1015
# Batch 61/1015 processed in 0.29 seconds (time per batch)
# Processing batch 62/1015
# Batch 62/1015 processed in 0.29 seconds (time per batch)
# Processing batch 63/1015
# Batch 63/1015 processed in 0.29 seconds (time per batch)
# Processing batch 64/1015
# Batch 64/1015 processed in 0.29 seconds (time per batch)
# Processing batch 65/1015
# Batch 65/1015 processed in 0.29 seconds (time per batch)
# Processing batch 66/1015
# Batch 66/1015 processed in 0.29 seconds (time per batch)
# Processing batch 67/1015
# Batch 67/1015 processed in 0.29 seconds (time per batch)
# Processing batch 68/1015
# Batch 68/1015 processed in 0.29 seconds (time per batch)
# Processing batch 69/1015
# Batch 69/1015 processed in 0.29 seconds (time per batch)
# Processing batch 70/1015
# Batch 70/1015 processed in 0.29 seconds (time per batch)
# Processing batch 71/1015
# Batch 71/1015 processed in 0.29 seconds (time per batch)
# Processing batch 72/1015
# Batch 72/1015 processed in 0.29 seconds (time per batch)
# Processing batch 73/1015
# Batch 73/1015 processed in 0.29 seconds (time per batch)
# Processing batch 74/1015
# Batch 74/1015 processed in 0.29 seconds (time per batch)
# Processing batch 75/1015
# Batch 75/1015 processed in 0.29 seconds (time per batch)
# Processing batch 76/1015
# Batch 76/1015 processed in 0.29 seconds (time per batch)
# Processing batch 77/1015
# Batch 77/1015 processed in 0.29 seconds (time per batch)
# Processing batch 78/1015
# Batch 78/1015 processed in 0.29 seconds (time per batch)
# Processing batch 79/1015
# Batch 79/1015 processed in 0.29 seconds (time per batch)
# Processing batch 80/1015
# Batch 80/1015 processed in 0.29 seconds (time per batch)
# Processing batch 81/1015
# Batch 81/1015 processed in 0.29 seconds (time per batch)
# Processing batch 82/1015
# Batch 82/1015 processed in 0.29 seconds (time per batch)
# Processing batch 83/1015
# Batch 83/1015 processed in 0.29 seconds (time per batch)
# Processing batch 84/1015
# Batch 84/1015 processed in 0.29 seconds (time per batch)
# Processing batch 85/1015
# Batch 85/1015 processed in 0.29 seconds (time per batch)
# Processing batch 86/1015
# Batch 86/1015 processed in 0.29 seconds (time per batch)
# Processing batch 87/1015
# Batch 87/1015 processed in 0.29 seconds (time per batch)
# Processing batch 88/1015
# Batch 88/1015 processed in 0.29 seconds (time per batch)
# Processing batch 89/1015
# Batch 89/1015 processed in 0.29 seconds (time per batch)
# Processing batch 90/1015
# Batch 90/1015 processed in 0.29 seconds (time per batch)
# Processing batch 91/1015
# Batch 91/1015 processed in 0.29 seconds (time per batch)
# Processing batch 92/1015
# Batch 92/1015 processed in 0.29 seconds (time per batch)
# Processing batch 93/1015
# Batch 93/1015 processed in 0.29 seconds (time per batch)
# Processing batch 94/1015
# Batch 94/1015 processed in 0.29 seconds (time per batch)
# Processing batch 95/1015
# Batch 95/1015 processed in 0.29 seconds (time per batch)
# Processing batch 96/1015
# Batch 96/1015 processed in 0.29 seconds (time per batch)
# Processing batch 97/1015
# Batch 97/1015 processed in 0.29 seconds (time per batch)
# Processing batch 98/1015
# Batch 98/1015 processed in 0.29 seconds (time per batch)
# Processing batch 99/1015
# Batch 99/1015 processed in 0.29 seconds (time per batch)
# Processing batch 100/1015
# Batch 100/1015 processed in 0.29 seconds (time per batch)
# Processing batch 101/1015
# Batch 101/1015 processed in 0.29 seconds (time per batch)
# Processing batch 102/1015
# Batch 102/1015 processed in 0.29 seconds (time per batch)
# Processing batch 103/1015
# Batch 103/1015 processed in 0.29 seconds (time per batch)
# Processing batch 104/1015
# Batch 104/1015 processed in 0.29 seconds (time per batch)
# Processing batch 105/1015
# Batch 105/1015 processed in 0.29 seconds (time per batch)
# Processing batch 106/1015
# Batch 106/1015 processed in 0.29 seconds (time per batch)
# Processing batch 107/1015
# Batch 107/1015 processed in 0.29 seconds (time per batch)
# Processing batch 108/1015
# Batch 108/1015 processed in 0.29 seconds (time per batch)
# Processing batch 109/1015
# Batch 109/1015 processed in 0.29 seconds (time per batch)
# Processing batch 110/1015
# Batch 110/1015 processed in 0.29 seconds (time per batch)
# Processing batch 111/1015
# Batch 111/1015 processed in 0.29 seconds (time per batch)
# Processing batch 112/1015
# Batch 112/1015 processed in 0.29 seconds (time per batch)
# Processing batch 113/1015
# Batch 113/1015 processed in 0.29 seconds (time per batch)
# Processing batch 114/1015
# Batch 114/1015 processed in 0.29 seconds (time per batch)
# Processing batch 115/1015
# Batch 115/1015 processed in 0.29 seconds (time per batch)
# Processing batch 116/1015
# Batch 116/1015 processed in 0.29 seconds (time per batch)
# Processing batch 117/1015
# Batch 117/1015 processed in 0.29 seconds (time per batch)
# Processing batch 118/1015
# Batch 118/1015 processed in 0.29 seconds (time per batch)
# Processing batch 119/1015
# Batch 119/1015 processed in 0.29 seconds (time per batch)
# Processing batch 120/1015
# Batch 120/1015 processed in 0.29 seconds (time per batch)
# Processing batch 121/1015
# Batch 121/1015 processed in 0.29 seconds (time per batch)
# Processing batch 122/1015
# Batch 122/1015 processed in 0.29 seconds (time per batch)
# Processing batch 123/1015
# Batch 123/1015 processed in 0.29 seconds (time per batch)
# Processing batch 124/1015
# Batch 124/1015 processed in 0.29 seconds (time per batch)
# Processing batch 125/1015
# Batch 125/1015 processed in 0.29 seconds (time per batch)
# Processing batch 126/1015
# Batch 126/1015 processed in 0.29 seconds (time per batch)
# Processing batch 127/1015
# Batch 127/1015 processed in 0.29 seconds (time per batch)
# Processing batch 128/1015
# Batch 128/1015 processed in 0.29 seconds (time per batch)
# Processing batch 129/1015
# Batch 129/1015 processed in 0.29 seconds (time per batch)
# Processing batch 130/1015
# Batch 130/1015 processed in 0.29 seconds (time per batch)
# Processing batch 131/1015
# Batch 131/1015 processed in 0.29 seconds (time per batch)
# Processing batch 132/1015
# Batch 132/1015 processed in 0.29 seconds (time per batch)
# Processing batch 133/1015
# Batch 133/1015 processed in 0.29 seconds (time per batch)
# Processing batch 134/1015
# Batch 134/1015 processed in 0.29 seconds (time per batch)
# Processing batch 135/1015
# Batch 135/1015 processed in 0.29 seconds (time per batch)
# Processing batch 136/1015
# Batch 136/1015 processed in 0.29 seconds (time per batch)
# Processing batch 137/1015
# Batch 137/1015 processed in 0.29 seconds (time per batch)
# Processing batch 138/1015
# Batch 138/1015 processed in 0.29 seconds (time per batch)
# Processing batch 139/1015
# Batch 139/1015 processed in 0.29 seconds (time per batch)
# Processing batch 140/1015
# Batch 140/1015 processed in 0.29 seconds (time per batch)
# Processing batch 141/1015
# Batch 141/1015 processed in 0.29 seconds (time per batch)
# Processing batch 142/1015
# Batch 142/1015 processed in 0.29 seconds (time per batch)
# Processing batch 143/1015
# Batch 143/1015 processed in 0.29 seconds (time per batch)
# Processing batch 144/1015
# Batch 144/1015 processed in 0.29 seconds (time per batch)
# Processing batch 145/1015
# Batch 145/1015 processed in 0.29 seconds (time per batch)
# Processing batch 146/1015
# Batch 146/1015 processed in 0.29 seconds (time per batch)
# Processing batch 147/1015
# Batch 147/1015 processed in 0.29 seconds (time per batch)
# Processing batch 148/1015
# Batch 148/1015 processed in 0.29 seconds (time per batch)
# Processing batch 149/1015
# Batch 149/1015 processed in 0.29 seconds (time per batch)
# Processing batch 150/1015
# Batch 150/1015 processed in 0.29 seconds (time per batch)
# Processing batch 151/1015
# Batch 151/1015 processed in 0.29 seconds (time per batch)
# Processing batch 152/1015
# Batch 152/1015 processed in 0.29 seconds (time per batch)
# Processing batch 153/1015
# Batch 153/1015 processed in 0.29 seconds (time per batch)
# Processing batch 154/1015
# Batch 154/1015 processed in 0.29 seconds (time per batch)
# Processing batch 155/1015
# Batch 155/1015 processed in 0.29 seconds (time per batch)
# Processing batch 156/1015
# Batch 156/1015 processed in 0.29 seconds (time per batch)
# Processing batch 157/1015
# Batch 157/1015 processed in 0.29 seconds (time per batch)
# Processing batch 158/1015
# Batch 158/1015 processed in 0.29 seconds (time per batch)
# Processing batch 159/1015
# Batch 159/1015 processed in 0.29 seconds (time per batch)
# Processing batch 160/1015
# Batch 160/1015 processed in 0.29 seconds (time per batch)
# Processing batch 161/1015
# Batch 161/1015 processed in 0.29 seconds (time per batch)
# Processing batch 162/1015
# Batch 162/1015 processed in 0.29 seconds (time per batch)
# Processing batch 163/1015
# Batch 163/1015 processed in 0.29 seconds (time per batch)
# Processing batch 164/1015
# Batch 164/1015 processed in 0.29 seconds (time per batch)
# Processing batch 165/1015
# Batch 165/1015 processed in 0.29 seconds (time per batch)
# Processing batch 166/1015
# Batch 166/1015 processed in 0.29 seconds (time per batch)
# Processing batch 167/1015
# Batch 167/1015 processed in 0.29 seconds (time per batch)
# Processing batch 168/1015
# Batch 168/1015 processed in 0.29 seconds (time per batch)
# Processing batch 169/1015
# Batch 169/1015 processed in 0.29 seconds (time per batch)
# Processing batch 170/1015
# Batch 170/1015 processed in 0.29 seconds (time per batch)
# Processing batch 171/1015
# Batch 171/1015 processed in 0.29 seconds (time per batch)
# Processing batch 172/1015
# Batch 172/1015 processed in 0.29 seconds (time per batch)
# Processing batch 173/1015
# Batch 173/1015 processed in 0.29 seconds (time per batch)
# Processing batch 174/1015
# Batch 174/1015 processed in 0.29 seconds (time per batch)
# Processing batch 175/1015
# Batch 175/1015 processed in 0.29 seconds (time per batch)
# Processing batch 176/1015
# Batch 176/1015 processed in 0.29 seconds (time per batch)
# Processing batch 177/1015
# Batch 177/1015 processed in 0.29 seconds (time per batch)
# Processing batch 178/1015
# Batch 178/1015 processed in 0.29 seconds (time per batch)
# Processing batch 179/1015
# Batch 179/1015 processed in 0.29 seconds (time per batch)
# Processing batch 180/1015
# Batch 180/1015 processed in 0.29 seconds (time per batch)
# Processing batch 181/1015
# Batch 181/1015 processed in 0.29 seconds (time per batch)
# Processing batch 182/1015
# Batch 182/1015 processed in 0.29 seconds (time per batch)
# Processing batch 183/1015
# Batch 183/1015 processed in 0.29 seconds (time per batch)
# Processing batch 184/1015
# Batch 184/1015 processed in 0.29 seconds (time per batch)
# Processing batch 185/1015
# Batch 185/1015 processed in 0.29 seconds (time per batch)
# Processing batch 186/1015
# Batch 186/1015 processed in 0.29 seconds (time per batch)
# Processing batch 187/1015
# Batch 187/1015 processed in 0.29 seconds (time per batch)
# Processing batch 188/1015
# Batch 188/1015 processed in 0.29 seconds (time per batch)
# Processing batch 189/1015
# Batch 189/1015 processed in 0.29 seconds (time per batch)
# Processing batch 190/1015
# Batch 190/1015 processed in 0.29 seconds (time per batch)
# Processing batch 191/1015
# Batch 191/1015 processed in 0.29 seconds (time per batch)
# Processing batch 192/1015
# Batch 192/1015 processed in 0.29 seconds (time per batch)
# Processing batch 193/1015
# Batch 193/1015 processed in 0.29 seconds (time per batch)
# Processing batch 194/1015
# Batch 194/1015 processed in 0.29 seconds (time per batch)
# Processing batch 195/1015
# Batch 195/1015 processed in 0.29 seconds (time per batch)
# Processing batch 196/1015
# Batch 196/1015 processed in 0.29 seconds (time per batch)
# Processing batch 197/1015
# Batch 197/1015 processed in 0.29 seconds (time per batch)
# Processing batch 198/1015
# Batch 198/1015 processed in 0.29 seconds (time per batch)
# Processing batch 199/1015
# Batch 199/1015 processed in 0.29 seconds (time per batch)
# Processing batch 200/1015
# Batch 200/1015 processed in 0.29 seconds (time per batch)
# Processing batch 201/1015
# Batch 201/1015 processed in 0.29 seconds (time per batch)
# Processing batch 202/1015
# Batch 202/1015 processed in 0.29 seconds (time per batch)
# Processing batch 203/1015
# Batch 203/1015 processed in 0.29 seconds (time per batch)
# Processing batch 204/1015
# Batch 204/1015 processed in 0.29 seconds (time per batch)
# Processing batch 205/1015
# Batch 205/1015 processed in 0.29 seconds (time per batch)
# Processing batch 206/1015
# Batch 206/1015 processed in 0.29 seconds (time per batch)
# Processing batch 207/1015
# Batch 207/1015 processed in 0.29 seconds (time per batch)
# Processing batch 208/1015
# Batch 208/1015 processed in 0.29 seconds (time per batch)
# Processing batch 209/1015
# Batch 209/1015 processed in 0.29 seconds (time per batch)
# Processing batch 210/1015
# Batch 210/1015 processed in 0.29 seconds (time per batch)
# Processing batch 211/1015
# Batch 211/1015 processed in 0.29 seconds (time per batch)
# Processing batch 212/1015
# Batch 212/1015 processed in 0.29 seconds (time per batch)
# Processing batch 213/1015
# Batch 213/1015 processed in 0.29 seconds (time per batch)
# Processing batch 214/1015
# Batch 214/1015 processed in 0.29 seconds (time per batch)
# Processing batch 215/1015
# Batch 215/1015 processed in 0.29 seconds (time per batch)
# Processing batch 216/1015
# Batch 216/1015 processed in 0.29 seconds (time per batch)
# Processing batch 217/1015
# Batch 217/1015 processed in 0.29 seconds (time per batch)
# Processing batch 218/1015
# Batch 218/1015 processed in 0.29 seconds (time per batch)
# Processing batch 219/1015
# Batch 219/1015 processed in 0.29 seconds (time per batch)
# Processing batch 220/1015
# Batch 220/1015 processed in 0.29 seconds (time per batch)
# Processing batch 221/1015
# Batch 221/1015 processed in 0.29 seconds (time per batch)
# Processing batch 222/1015
# Batch 222/1015 processed in 0.29 seconds (time per batch)
# Processing batch 223/1015
# Batch 223/1015 processed in 0.29 seconds (time per batch)
# Processing batch 224/1015
# Batch 224/1015 processed in 0.29 seconds (time per batch)
# Processing batch 225/1015
# Batch 225/1015 processed in 0.29 seconds (time per batch)
# Processing batch 226/1015
# Batch 226/1015 processed in 0.29 seconds (time per batch)
# Processing batch 227/1015
# Batch 227/1015 processed in 0.29 seconds (time per batch)
# Processing batch 228/1015
# Batch 228/1015 processed in 0.29 seconds (time per batch)
# Processing batch 229/1015
# Batch 229/1015 processed in 0.29 seconds (time per batch)
# Processing batch 230/1015
# Batch 230/1015 processed in 0.29 seconds (time per batch)
# Processing batch 231/1015
# Batch 231/1015 processed in 0.29 seconds (time per batch)
# Processing batch 232/1015
# Batch 232/1015 processed in 0.29 seconds (time per batch)
# Processing batch 233/1015
# Batch 233/1015 processed in 0.29 seconds (time per batch)
# Processing batch 234/1015
# Batch 234/1015 processed in 0.29 seconds (time per batch)
# Processing batch 235/1015
# Batch 235/1015 processed in 0.29 seconds (time per batch)
# Processing batch 236/1015
# Batch 236/1015 processed in 0.29 seconds (time per batch)
# Processing batch 237/1015
# Batch 237/1015 processed in 0.29 seconds (time per batch)
# Processing batch 238/1015
# Batch 238/1015 processed in 0.29 seconds (time per batch)
# Processing batch 239/1015
# Batch 239/1015 processed in 0.29 seconds (time per batch)
# Processing batch 240/1015
# Batch 240/1015 processed in 0.29 seconds (time per batch)
# Processing batch 241/1015
# Batch 241/1015 processed in 0.29 seconds (time per batch)
# Processing batch 242/1015
# Batch 242/1015 processed in 0.29 seconds (time per batch)
# Processing batch 243/1015
# Batch 243/1015 processed in 0.29 seconds (time per batch)
# Processing batch 244/1015
# Batch 244/1015 processed in 0.29 seconds (time per batch)
# Processing batch 245/1015
# Batch 245/1015 processed in 0.29 seconds (time per batch)
# Processing batch 246/1015
# Batch 246/1015 processed in 0.29 seconds (time per batch)
# Processing batch 247/1015
# Batch 247/1015 processed in 0.29 seconds (time per batch)
# Processing batch 248/1015
# Batch 248/1015 processed in 0.29 seconds (time per batch)
# Processing batch 249/1015
# Batch 249/1015 processed in 0.29 seconds (time per batch)
# Processing batch 250/1015
# Batch 250/1015 processed in 0.29 seconds (time per batch)
# Processing batch 251/1015
# Batch 251/1015 processed in 0.29 seconds (time per batch)
# Processing batch 252/1015
# Batch 252/1015 processed in 0.29 seconds (time per batch)
# Processing batch 253/1015
# Batch 253/1015 processed in 0.29 seconds (time per batch)
# Processing batch 254/1015
# Batch 254/1015 processed in 0.29 seconds (time per batch)
# Processing batch 255/1015
# Batch 255/1015 processed in 0.29 seconds (time per batch)
# Processing batch 256/1015
# Batch 256/1015 processed in 0.30 seconds (time per batch)
# Processing batch 257/1015
# Batch 257/1015 processed in 0.29 seconds (time per batch)
# Processing batch 258/1015
# Batch 258/1015 processed in 0.29 seconds (time per batch)
# Processing batch 259/1015
# Batch 259/1015 processed in 0.29 seconds (time per batch)
# Processing batch 260/1015
# Batch 260/1015 processed in 0.29 seconds (time per batch)
# Processing batch 261/1015
# Batch 261/1015 processed in 0.29 seconds (time per batch)
# Processing batch 262/1015
# Batch 262/1015 processed in 0.29 seconds (time per batch)
# Processing batch 263/1015
# Batch 263/1015 processed in 0.29 seconds (time per batch)
# Processing batch 264/1015
# Batch 264/1015 processed in 0.29 seconds (time per batch)
# Processing batch 265/1015
# Batch 265/1015 processed in 0.29 seconds (time per batch)
# Processing batch 266/1015
# Batch 266/1015 processed in 0.29 seconds (time per batch)
# Processing batch 267/1015
# Batch 267/1015 processed in 0.29 seconds (time per batch)
# Processing batch 268/1015
# Batch 268/1015 processed in 0.29 seconds (time per batch)
# Processing batch 269/1015
# Batch 269/1015 processed in 0.30 seconds (time per batch)
# Processing batch 270/1015
# Batch 270/1015 processed in 0.29 seconds (time per batch)
# Processing batch 271/1015
# Batch 271/1015 processed in 0.29 seconds (time per batch)
# Processing batch 272/1015
# Batch 272/1015 processed in 0.29 seconds (time per batch)
# Processing batch 273/1015
# Batch 273/1015 processed in 0.29 seconds (time per batch)
# Processing batch 274/1015
# Batch 274/1015 processed in 0.29 seconds (time per batch)
# Processing batch 275/1015
# Batch 275/1015 processed in 0.29 seconds (time per batch)
# Processing batch 276/1015
# Batch 276/1015 processed in 0.29 seconds (time per batch)
# Processing batch 277/1015
# Batch 277/1015 processed in 0.29 seconds (time per batch)
# Processing batch 278/1015
# Batch 278/1015 processed in 0.29 seconds (time per batch)
# Processing batch 279/1015
# Batch 279/1015 processed in 0.29 seconds (time per batch)
# Processing batch 280/1015
# Batch 280/1015 processed in 0.29 seconds (time per batch)
# Processing batch 281/1015
# Batch 281/1015 processed in 0.29 seconds (time per batch)
# Processing batch 282/1015
# Batch 282/1015 processed in 0.29 seconds (time per batch)
# Processing batch 283/1015
# Batch 283/1015 processed in 0.29 seconds (time per batch)
# Processing batch 284/1015
# Batch 284/1015 processed in 0.29 seconds (time per batch)
# Processing batch 285/1015
# Batch 285/1015 processed in 0.29 seconds (time per batch)
# Processing batch 286/1015
# Batch 286/1015 processed in 0.29 seconds (time per batch)
# Processing batch 287/1015
# Batch 287/1015 processed in 0.29 seconds (time per batch)
# Processing batch 288/1015
# Batch 288/1015 processed in 0.29 seconds (time per batch)
# Processing batch 289/1015
# Batch 289/1015 processed in 0.29 seconds (time per batch)
# Processing batch 290/1015
# Batch 290/1015 processed in 0.29 seconds (time per batch)
# Processing batch 291/1015
# Batch 291/1015 processed in 0.29 seconds (time per batch)
# Processing batch 292/1015
# Batch 292/1015 processed in 0.29 seconds (time per batch)
# Processing batch 293/1015
# Batch 293/1015 processed in 0.29 seconds (time per batch)
# Processing batch 294/1015
# Batch 294/1015 processed in 0.29 seconds (time per batch)
# Processing batch 295/1015
# Batch 295/1015 processed in 0.29 seconds (time per batch)
# Processing batch 296/1015
# Batch 296/1015 processed in 0.29 seconds (time per batch)
# Processing batch 297/1015
# Batch 297/1015 processed in 0.29 seconds (time per batch)
# Processing batch 298/1015
# Batch 298/1015 processed in 0.29 seconds (time per batch)
# Processing batch 299/1015
# Batch 299/1015 processed in 0.29 seconds (time per batch)
# Processing batch 300/1015
# Batch 300/1015 processed in 0.29 seconds (time per batch)
# Processing batch 301/1015
# Batch 301/1015 processed in 0.29 seconds (time per batch)
# Processing batch 302/1015
# Batch 302/1015 processed in 0.29 seconds (time per batch)
# Processing batch 303/1015
# Batch 303/1015 processed in 0.29 seconds (time per batch)
# Processing batch 304/1015
# Batch 304/1015 processed in 0.29 seconds (time per batch)
# Processing batch 305/1015
# Batch 305/1015 processed in 0.29 seconds (time per batch)
# Processing batch 306/1015
# Batch 306/1015 processed in 0.29 seconds (time per batch)
# Processing batch 307/1015
# Batch 307/1015 processed in 0.29 seconds (time per batch)
# Processing batch 308/1015
# Batch 308/1015 processed in 0.29 seconds (time per batch)
# Processing batch 309/1015
# Batch 309/1015 processed in 0.29 seconds (time per batch)
# Processing batch 310/1015
# Batch 310/1015 processed in 0.29 seconds (time per batch)
# Processing batch 311/1015
# Batch 311/1015 processed in 0.29 seconds (time per batch)
# Processing batch 312/1015
# Batch 312/1015 processed in 0.29 seconds (time per batch)
# Processing batch 313/1015
# Batch 313/1015 processed in 0.29 seconds (time per batch)
# Processing batch 314/1015
# Batch 314/1015 processed in 0.29 seconds (time per batch)
# Processing batch 315/1015
# Batch 315/1015 processed in 0.29 seconds (time per batch)
# Processing batch 316/1015
# Batch 316/1015 processed in 0.29 seconds (time per batch)
# Processing batch 317/1015
# Batch 317/1015 processed in 0.29 seconds (time per batch)
# Processing batch 318/1015
# Batch 318/1015 processed in 0.29 seconds (time per batch)
# Processing batch 319/1015
# Batch 319/1015 processed in 0.29 seconds (time per batch)
# Processing batch 320/1015
# Batch 320/1015 processed in 0.29 seconds (time per batch)
# Processing batch 321/1015
# Batch 321/1015 processed in 0.29 seconds (time per batch)
# Processing batch 322/1015
# Batch 322/1015 processed in 0.29 seconds (time per batch)
# Processing batch 323/1015
# Batch 323/1015 processed in 0.29 seconds (time per batch)
# Processing batch 324/1015
# Batch 324/1015 processed in 0.29 seconds (time per batch)
# Processing batch 325/1015
# Batch 325/1015 processed in 0.29 seconds (time per batch)
# Processing batch 326/1015
# Batch 326/1015 processed in 0.29 seconds (time per batch)
# Processing batch 327/1015
# Batch 327/1015 processed in 0.29 seconds (time per batch)
# Processing batch 328/1015
# Batch 328/1015 processed in 0.29 seconds (time per batch)
# Processing batch 329/1015
# Batch 329/1015 processed in 0.29 seconds (time per batch)
# Processing batch 330/1015
# Batch 330/1015 processed in 0.29 seconds (time per batch)
# Processing batch 331/1015
# Batch 331/1015 processed in 0.29 seconds (time per batch)
# Processing batch 332/1015
# Batch 332/1015 processed in 0.29 seconds (time per batch)
# Processing batch 333/1015
# Batch 333/1015 processed in 0.29 seconds (time per batch)
# Processing batch 334/1015
# Batch 334/1015 processed in 0.29 seconds (time per batch)
# Processing batch 335/1015
# Batch 335/1015 processed in 0.29 seconds (time per batch)
# Processing batch 336/1015
# Batch 336/1015 processed in 0.29 seconds (time per batch)
# Processing batch 337/1015
# Batch 337/1015 processed in 0.29 seconds (time per batch)
# Processing batch 338/1015
# Batch 338/1015 processed in 0.29 seconds (time per batch)
# Processing batch 339/1015
# Batch 339/1015 processed in 0.29 seconds (time per batch)
# Processing batch 340/1015
# Batch 340/1015 processed in 0.29 seconds (time per batch)
# Processing batch 341/1015
# Batch 341/1015 processed in 0.29 seconds (time per batch)
# Processing batch 342/1015
# Batch 342/1015 processed in 0.29 seconds (time per batch)
# Processing batch 343/1015
# Batch 343/1015 processed in 0.29 seconds (time per batch)
# Processing batch 344/1015
# Batch 344/1015 processed in 0.29 seconds (time per batch)
# Processing batch 345/1015
# Batch 345/1015 processed in 0.29 seconds (time per batch)
# Processing batch 346/1015
# Batch 346/1015 processed in 0.29 seconds (time per batch)
# Processing batch 347/1015
# Batch 347/1015 processed in 0.29 seconds (time per batch)
# Processing batch 348/1015
# Batch 348/1015 processed in 0.29 seconds (time per batch)
# Processing batch 349/1015
# Batch 349/1015 processed in 0.29 seconds (time per batch)
# Processing batch 350/1015
# Batch 350/1015 processed in 0.29 seconds (time per batch)
# Processing batch 351/1015
# Batch 351/1015 processed in 0.29 seconds (time per batch)
# Processing batch 352/1015
# Batch 352/1015 processed in 0.29 seconds (time per batch)
# Processing batch 353/1015
# Batch 353/1015 processed in 0.29 seconds (time per batch)
# Processing batch 354/1015
# Batch 354/1015 processed in 0.29 seconds (time per batch)
# Processing batch 355/1015
# Batch 355/1015 processed in 0.29 seconds (time per batch)
# Processing batch 356/1015
# Batch 356/1015 processed in 0.29 seconds (time per batch)
# Processing batch 357/1015
# Batch 357/1015 processed in 0.29 seconds (time per batch)
# Processing batch 358/1015
# Batch 358/1015 processed in 0.29 seconds (time per batch)
# Processing batch 359/1015
# Batch 359/1015 processed in 0.29 seconds (time per batch)
# Processing batch 360/1015
# Batch 360/1015 processed in 0.29 seconds (time per batch)
# Processing batch 361/1015
# Batch 361/1015 processed in 0.29 seconds (time per batch)
# Processing batch 362/1015
# Batch 362/1015 processed in 0.29 seconds (time per batch)
# Processing batch 363/1015
# Batch 363/1015 processed in 0.29 seconds (time per batch)
# Processing batch 364/1015
# Batch 364/1015 processed in 0.29 seconds (time per batch)
# Processing batch 365/1015
# Batch 365/1015 processed in 0.29 seconds (time per batch)
# Processing batch 366/1015
# Batch 366/1015 processed in 0.29 seconds (time per batch)
# Processing batch 367/1015
# Batch 367/1015 processed in 0.29 seconds (time per batch)
# Processing batch 368/1015
# Batch 368/1015 processed in 0.29 seconds (time per batch)
# Processing batch 369/1015
# Batch 369/1015 processed in 0.29 seconds (time per batch)
# Processing batch 370/1015
# Batch 370/1015 processed in 0.29 seconds (time per batch)
# Processing batch 371/1015
# Batch 371/1015 processed in 0.29 seconds (time per batch)
# Processing batch 372/1015
# Batch 372/1015 processed in 0.29 seconds (time per batch)
# Processing batch 373/1015
# Batch 373/1015 processed in 0.29 seconds (time per batch)
# Processing batch 374/1015
# Batch 374/1015 processed in 0.29 seconds (time per batch)
# Processing batch 375/1015
# Batch 375/1015 processed in 0.29 seconds (time per batch)
# Processing batch 376/1015
# Batch 376/1015 processed in 0.29 seconds (time per batch)
# Processing batch 377/1015
# Batch 377/1015 processed in 0.29 seconds (time per batch)
# Processing batch 378/1015
# Batch 378/1015 processed in 0.29 seconds (time per batch)
# Processing batch 379/1015
# Batch 379/1015 processed in 0.29 seconds (time per batch)
# Processing batch 380/1015
# Batch 380/1015 processed in 0.29 seconds (time per batch)
# Processing batch 381/1015
# Batch 381/1015 processed in 0.29 seconds (time per batch)
# Processing batch 382/1015
# Batch 382/1015 processed in 0.29 seconds (time per batch)
# Processing batch 383/1015
# Batch 383/1015 processed in 0.29 seconds (time per batch)
# Processing batch 384/1015
# Batch 384/1015 processed in 0.29 seconds (time per batch)
# Processing batch 385/1015
# Batch 385/1015 processed in 0.29 seconds (time per batch)
# Processing batch 386/1015
# Batch 386/1015 processed in 0.29 seconds (time per batch)
# Processing batch 387/1015
# Batch 387/1015 processed in 0.29 seconds (time per batch)
# Processing batch 388/1015
# Batch 388/1015 processed in 0.29 seconds (time per batch)
# Processing batch 389/1015
# Batch 389/1015 processed in 0.29 seconds (time per batch)
# Processing batch 390/1015
# Batch 390/1015 processed in 0.29 seconds (time per batch)
# Processing batch 391/1015
# Batch 391/1015 processed in 0.29 seconds (time per batch)
# Processing batch 392/1015
# Batch 392/1015 processed in 0.29 seconds (time per batch)
# Processing batch 393/1015
# Batch 393/1015 processed in 0.29 seconds (time per batch)
# Processing batch 394/1015
# Batch 394/1015 processed in 0.29 seconds (time per batch)
# Processing batch 395/1015
# Batch 395/1015 processed in 0.29 seconds (time per batch)
# Processing batch 396/1015
# Batch 396/1015 processed in 0.29 seconds (time per batch)
# Processing batch 397/1015
# Batch 397/1015 processed in 0.29 seconds (time per batch)
# Processing batch 398/1015
# Batch 398/1015 processed in 0.29 seconds (time per batch)
# Processing batch 399/1015
# Batch 399/1015 processed in 0.29 seconds (time per batch)
# Processing batch 400/1015
# Batch 400/1015 processed in 0.29 seconds (time per batch)
# Processing batch 401/1015
# Batch 401/1015 processed in 0.29 seconds (time per batch)
# Processing batch 402/1015
# Batch 402/1015 processed in 0.29 seconds (time per batch)
# Processing batch 403/1015
# Batch 403/1015 processed in 0.29 seconds (time per batch)
# Processing batch 404/1015
# Batch 404/1015 processed in 0.29 seconds (time per batch)
# Processing batch 405/1015
# Batch 405/1015 processed in 0.29 seconds (time per batch)
# Processing batch 406/1015
# Batch 406/1015 processed in 0.29 seconds (time per batch)
# Processing batch 407/1015
# Batch 407/1015 processed in 0.29 seconds (time per batch)
# Processing batch 408/1015
# Batch 408/1015 processed in 0.29 seconds (time per batch)
# Processing batch 409/1015
# Batch 409/1015 processed in 0.29 seconds (time per batch)
# Processing batch 410/1015
# Batch 410/1015 processed in 0.29 seconds (time per batch)
# Processing batch 411/1015
# Batch 411/1015 processed in 0.29 seconds (time per batch)
# Processing batch 412/1015
# Batch 412/1015 processed in 0.29 seconds (time per batch)
# Processing batch 413/1015
# Batch 413/1015 processed in 0.29 seconds (time per batch)
# Processing batch 414/1015
# Batch 414/1015 processed in 0.29 seconds (time per batch)
# Processing batch 415/1015
# Batch 415/1015 processed in 0.29 seconds (time per batch)
# Processing batch 416/1015
# Batch 416/1015 processed in 0.29 seconds (time per batch)
# Processing batch 417/1015
# Batch 417/1015 processed in 0.29 seconds (time per batch)
# Processing batch 418/1015
# Batch 418/1015 processed in 0.29 seconds (time per batch)
# Processing batch 419/1015
# Batch 419/1015 processed in 0.29 seconds (time per batch)
# Processing batch 420/1015
# Batch 420/1015 processed in 0.29 seconds (time per batch)
# Processing batch 421/1015
# Batch 421/1015 processed in 0.29 seconds (time per batch)
# Processing batch 422/1015
# Batch 422/1015 processed in 0.29 seconds (time per batch)
# Processing batch 423/1015
# Batch 423/1015 processed in 0.29 seconds (time per batch)
# Processing batch 424/1015
# Batch 424/1015 processed in 0.29 seconds (time per batch)
# Processing batch 425/1015
# Batch 425/1015 processed in 0.29 seconds (time per batch)
# Processing batch 426/1015
# Batch 426/1015 processed in 0.29 seconds (time per batch)
# Processing batch 427/1015
# Batch 427/1015 processed in 0.29 seconds (time per batch)
# Processing batch 428/1015
# Batch 428/1015 processed in 0.29 seconds (time per batch)
# Processing batch 429/1015
# Batch 429/1015 processed in 0.29 seconds (time per batch)
# Processing batch 430/1015
# Batch 430/1015 processed in 0.29 seconds (time per batch)
# Processing batch 431/1015
# Batch 431/1015 processed in 0.29 seconds (time per batch)
# Processing batch 432/1015
# Batch 432/1015 processed in 0.29 seconds (time per batch)
# Processing batch 433/1015
# Batch 433/1015 processed in 0.29 seconds (time per batch)
# Processing batch 434/1015
# Batch 434/1015 processed in 0.29 seconds (time per batch)
# Processing batch 435/1015
# Batch 435/1015 processed in 0.29 seconds (time per batch)
# Processing batch 436/1015
# Batch 436/1015 processed in 0.29 seconds (time per batch)
# Processing batch 437/1015
# Batch 437/1015 processed in 0.29 seconds (time per batch)
# Processing batch 438/1015
# Batch 438/1015 processed in 0.29 seconds (time per batch)
# Processing batch 439/1015
# Batch 439/1015 processed in 0.29 seconds (time per batch)
# Processing batch 440/1015
# Batch 440/1015 processed in 0.29 seconds (time per batch)
# Processing batch 441/1015
# Batch 441/1015 processed in 0.29 seconds (time per batch)
# Processing batch 442/1015
# Batch 442/1015 processed in 0.29 seconds (time per batch)
# Processing batch 443/1015
# Batch 443/1015 processed in 0.29 seconds (time per batch)
# Processing batch 444/1015
# Batch 444/1015 processed in 0.29 seconds (time per batch)
# Processing batch 445/1015
# Batch 445/1015 processed in 0.29 seconds (time per batch)
# Processing batch 446/1015
# Batch 446/1015 processed in 0.29 seconds (time per batch)
# Processing batch 447/1015
# Batch 447/1015 processed in 0.29 seconds (time per batch)
# Processing batch 448/1015
# Batch 448/1015 processed in 0.29 seconds (time per batch)
# Processing batch 449/1015
# Batch 449/1015 processed in 0.29 seconds (time per batch)
# Processing batch 450/1015
# Batch 450/1015 processed in 0.29 seconds (time per batch)
# Processing batch 451/1015
# Batch 451/1015 processed in 0.29 seconds (time per batch)
# Processing batch 452/1015
# Batch 452/1015 processed in 0.29 seconds (time per batch)
# Processing batch 453/1015
# Batch 453/1015 processed in 0.29 seconds (time per batch)
# Processing batch 454/1015
# Batch 454/1015 processed in 0.29 seconds (time per batch)
# Processing batch 455/1015
# Batch 455/1015 processed in 0.29 seconds (time per batch)
# Processing batch 456/1015
# Batch 456/1015 processed in 0.29 seconds (time per batch)
# Processing batch 457/1015
# Batch 457/1015 processed in 0.29 seconds (time per batch)
# Processing batch 458/1015
# Batch 458/1015 processed in 0.29 seconds (time per batch)
# Processing batch 459/1015
# Batch 459/1015 processed in 0.29 seconds (time per batch)
# Processing batch 460/1015
# Batch 460/1015 processed in 0.29 seconds (time per batch)
# Processing batch 461/1015
# Batch 461/1015 processed in 0.29 seconds (time per batch)
# Processing batch 462/1015
# Batch 462/1015 processed in 0.29 seconds (time per batch)
# Processing batch 463/1015
# Batch 463/1015 processed in 0.29 seconds (time per batch)
# Processing batch 464/1015
# Batch 464/1015 processed in 0.29 seconds (time per batch)
# Processing batch 465/1015
# Batch 465/1015 processed in 0.29 seconds (time per batch)
# Processing batch 466/1015
# Batch 466/1015 processed in 0.29 seconds (time per batch)
# Processing batch 467/1015
# Batch 467/1015 processed in 0.29 seconds (time per batch)
# Processing batch 468/1015
# Batch 468/1015 processed in 0.29 seconds (time per batch)
# Processing batch 469/1015
# Batch 469/1015 processed in 0.29 seconds (time per batch)
# Processing batch 470/1015
# Batch 470/1015 processed in 0.29 seconds (time per batch)
# Processing batch 471/1015
# Batch 471/1015 processed in 0.29 seconds (time per batch)
# Processing batch 472/1015
# Batch 472/1015 processed in 0.29 seconds (time per batch)
# Processing batch 473/1015
# Batch 473/1015 processed in 0.29 seconds (time per batch)
# Processing batch 474/1015
# Batch 474/1015 processed in 0.29 seconds (time per batch)
# Processing batch 475/1015
# Batch 475/1015 processed in 0.29 seconds (time per batch)
# Processing batch 476/1015
# Batch 476/1015 processed in 0.29 seconds (time per batch)
# Processing batch 477/1015
# Batch 477/1015 processed in 0.29 seconds (time per batch)
# Processing batch 478/1015
# Batch 478/1015 processed in 0.29 seconds (time per batch)
# Processing batch 479/1015
# Batch 479/1015 processed in 0.29 seconds (time per batch)
# Processing batch 480/1015
# Batch 480/1015 processed in 0.29 seconds (time per batch)
# Processing batch 481/1015
# Batch 481/1015 processed in 0.29 seconds (time per batch)
# Processing batch 482/1015
# Batch 482/1015 processed in 0.29 seconds (time per batch)
# Processing batch 483/1015
# Batch 483/1015 processed in 0.29 seconds (time per batch)
# Processing batch 484/1015
# Batch 484/1015 processed in 0.29 seconds (time per batch)
# Processing batch 485/1015
# Batch 485/1015 processed in 0.29 seconds (time per batch)
# Processing batch 486/1015
# Batch 486/1015 processed in 0.29 seconds (time per batch)
# Processing batch 487/1015
# Batch 487/1015 processed in 0.29 seconds (time per batch)
# Processing batch 488/1015
# Batch 488/1015 processed in 0.29 seconds (time per batch)
# Processing batch 489/1015
# Batch 489/1015 processed in 0.29 seconds (time per batch)
# Processing batch 490/1015
# Batch 490/1015 processed in 0.29 seconds (time per batch)
# Processing batch 491/1015
# Batch 491/1015 processed in 0.29 seconds (time per batch)
# Processing batch 492/1015
# Batch 492/1015 processed in 0.29 seconds (time per batch)
# Processing batch 493/1015
# Batch 493/1015 processed in 0.29 seconds (time per batch)
# Processing batch 494/1015
# Batch 494/1015 processed in 0.29 seconds (time per batch)
# Processing batch 495/1015
# Batch 495/1015 processed in 0.29 seconds (time per batch)
# Processing batch 496/1015
# Batch 496/1015 processed in 0.29 seconds (time per batch)
# Processing batch 497/1015
# Batch 497/1015 processed in 0.29 seconds (time per batch)
# Processing batch 498/1015
# Batch 498/1015 processed in 0.29 seconds (time per batch)
# Processing batch 499/1015
# Batch 499/1015 processed in 0.29 seconds (time per batch)
# Processing batch 500/1015
# Batch 500/1015 processed in 0.29 seconds (time per batch)
# Processing batch 501/1015
# Batch 501/1015 processed in 0.29 seconds (time per batch)
# Processing batch 502/1015
# Batch 502/1015 processed in 0.29 seconds (time per batch)
# Processing batch 503/1015
# Batch 503/1015 processed in 0.29 seconds (time per batch)
# Processing batch 504/1015
# Batch 504/1015 processed in 0.29 seconds (time per batch)
# Processing batch 505/1015
# Batch 505/1015 processed in 0.29 seconds (time per batch)
# Processing batch 506/1015
# Batch 506/1015 processed in 0.29 seconds (time per batch)
# Processing batch 507/1015
# Batch 507/1015 processed in 0.29 seconds (time per batch)
# Processing batch 508/1015
# Batch 508/1015 processed in 0.29 seconds (time per batch)
# Processing batch 509/1015
# Batch 509/1015 processed in 0.29 seconds (time per batch)
# Processing batch 510/1015
# Batch 510/1015 processed in 0.29 seconds (time per batch)
# Processing batch 511/1015
# Batch 511/1015 processed in 0.29 seconds (time per batch)
# Processing batch 512/1015
# Batch 512/1015 processed in 0.29 seconds (time per batch)
# Processing batch 513/1015
# Batch 513/1015 processed in 0.29 seconds (time per batch)
# Processing batch 514/1015
# Batch 514/1015 processed in 0.29 seconds (time per batch)
# Processing batch 515/1015
# Batch 515/1015 processed in 0.29 seconds (time per batch)
# Processing batch 516/1015
# Batch 516/1015 processed in 0.29 seconds (time per batch)
# Processing batch 517/1015
# Batch 517/1015 processed in 0.29 seconds (time per batch)
# Processing batch 518/1015
# Batch 518/1015 processed in 0.29 seconds (time per batch)
# Processing batch 519/1015
# Batch 519/1015 processed in 0.29 seconds (time per batch)
# Processing batch 520/1015
# Batch 520/1015 processed in 0.29 seconds (time per batch)
# Processing batch 521/1015
# Batch 521/1015 processed in 0.29 seconds (time per batch)
# Processing batch 522/1015
# Batch 522/1015 processed in 0.29 seconds (time per batch)
# Processing batch 523/1015
# Batch 523/1015 processed in 0.29 seconds (time per batch)
# Processing batch 524/1015
# Batch 524/1015 processed in 0.29 seconds (time per batch)
# Processing batch 525/1015
# Batch 525/1015 processed in 0.29 seconds (time per batch)
# Processing batch 526/1015
# Batch 526/1015 processed in 0.29 seconds (time per batch)
# Processing batch 527/1015
# Batch 527/1015 processed in 0.29 seconds (time per batch)
# Processing batch 528/1015
# Batch 528/1015 processed in 0.29 seconds (time per batch)
# Processing batch 529/1015
# Batch 529/1015 processed in 0.29 seconds (time per batch)
# Processing batch 530/1015
# Batch 530/1015 processed in 0.29 seconds (time per batch)
# Processing batch 531/1015
# Batch 531/1015 processed in 0.29 seconds (time per batch)
# Processing batch 532/1015
# Batch 532/1015 processed in 0.29 seconds (time per batch)
# Processing batch 533/1015
# Batch 533/1015 processed in 0.29 seconds (time per batch)
# Processing batch 534/1015
# Batch 534/1015 processed in 0.29 seconds (time per batch)
# Processing batch 535/1015
# Batch 535/1015 processed in 0.29 seconds (time per batch)
# Processing batch 536/1015
# Batch 536/1015 processed in 0.29 seconds (time per batch)
# Processing batch 537/1015
# Batch 537/1015 processed in 0.29 seconds (time per batch)
# Processing batch 538/1015
# Batch 538/1015 processed in 0.29 seconds (time per batch)
# Processing batch 539/1015
# Batch 539/1015 processed in 0.29 seconds (time per batch)
# Processing batch 540/1015
# Batch 540/1015 processed in 0.29 seconds (time per batch)
# Processing batch 541/1015
# Batch 541/1015 processed in 0.29 seconds (time per batch)
# Processing batch 542/1015
# Batch 542/1015 processed in 0.29 seconds (time per batch)
# Processing batch 543/1015
# Batch 543/1015 processed in 0.29 seconds (time per batch)
# Processing batch 544/1015
# Batch 544/1015 processed in 0.29 seconds (time per batch)
# Processing batch 545/1015
# Batch 545/1015 processed in 0.29 seconds (time per batch)
# Processing batch 546/1015
# Batch 546/1015 processed in 0.29 seconds (time per batch)
# Processing batch 547/1015
# Batch 547/1015 processed in 0.29 seconds (time per batch)
# Processing batch 548/1015
# Batch 548/1015 processed in 0.29 seconds (time per batch)
# Processing batch 549/1015
# Batch 549/1015 processed in 0.29 seconds (time per batch)
# Processing batch 550/1015
# Batch 550/1015 processed in 0.29 seconds (time per batch)
# Processing batch 551/1015
# Batch 551/1015 processed in 0.29 seconds (time per batch)
# Processing batch 552/1015
# Batch 552/1015 processed in 0.29 seconds (time per batch)
# Processing batch 553/1015
# Batch 553/1015 processed in 0.29 seconds (time per batch)
# Processing batch 554/1015
# Batch 554/1015 processed in 0.29 seconds (time per batch)
# Processing batch 555/1015
# Batch 555/1015 processed in 0.29 seconds (time per batch)
# Processing batch 556/1015
# Batch 556/1015 processed in 0.29 seconds (time per batch)
# Processing batch 557/1015
# Batch 557/1015 processed in 0.29 seconds (time per batch)
# Processing batch 558/1015
# Batch 558/1015 processed in 0.29 seconds (time per batch)
# Processing batch 559/1015
# Batch 559/1015 processed in 0.29 seconds (time per batch)
# Processing batch 560/1015
# Batch 560/1015 processed in 0.29 seconds (time per batch)
# Processing batch 561/1015
# Batch 561/1015 processed in 0.29 seconds (time per batch)
# Processing batch 562/1015
# Batch 562/1015 processed in 0.29 seconds (time per batch)
# Processing batch 563/1015
# Batch 563/1015 processed in 0.29 seconds (time per batch)
# Processing batch 564/1015
# Batch 564/1015 processed in 0.29 seconds (time per batch)
# Processing batch 565/1015
# Batch 565/1015 processed in 0.29 seconds (time per batch)
# Processing batch 566/1015
# ...
# Batch 875/1015 processed in 0.59 seconds (time per batch)
# Processing batch 876/1015
# Batch 876/1015 processed in 0.59 seconds (time per batch)
# Processing batch 877/1015
# Batch 877/1015 processed in 0.59 seconds (time per batch)
# Processing batch 878/1015
# Batch 878/1015 processed in 0.59 seconds (time per batch)
# Processing batch 879/1015
# Batch 879/1015 processed in 0.59 seconds (time per batch)
# Processing batch 880/1015
# Batch 880/1015 processed in 0.59 seconds (time per batch)
# Processing batch 881/1015
# Batch 881/1015 processed in 0.59 seconds (time per batch)
# Processing batch 882/1015
# Batch 882/1015 processed in 0.59 seconds (time per batch)
# Processing batch 883/1015
# Batch 883/1015 processed in 0.59 seconds (time per batch)
# Processing batch 884/1015
# Batch 884/1015 processed in 0.59 seconds (time per batch)
# Processing batch 885/1015
# Batch 885/1015 processed in 0.58 seconds (time per batch)
# Processing batch 886/1015
# Batch 886/1015 processed in 0.59 seconds (time per batch)
# Processing batch 887/1015
# Batch 887/1015 processed in 0.59 seconds (time per batch)
# Processing batch 888/1015
# Batch 888/1015 processed in 0.59 seconds (time per batch)
# Processing batch 889/1015
# Batch 889/1015 processed in 0.59 seconds (time per batch)
# Processing batch 890/1015
# Batch 890/1015 processed in 0.59 seconds (time per batch)
# Processing batch 891/1015
# Batch 891/1015 processed in 0.59 seconds (time per batch)
# Processing batch 892/1015
# Batch 892/1015 processed in 0.59 seconds (time per batch)
# Processing batch 893/1015
# Batch 893/1015 processed in 0.58 seconds (time per batch)
# Processing batch 894/1015
# Batch 894/1015 processed in 0.59 seconds (time per batch)
# Processing batch 895/1015
# Batch 895/1015 processed in 0.59 seconds (time per batch)
# Processing batch 896/1015
# Batch 896/1015 processed in 0.59 seconds (time per batch)
# Processing batch 897/1015
# Batch 897/1015 processed in 0.59 seconds (time per batch)
# Processing batch 898/1015
# Batch 898/1015 processed in 0.59 seconds (time per batch)
# Processing batch 899/1015
# Batch 899/1015 processed in 0.59 seconds (time per batch)
# Processing batch 900/1015
# Batch 900/1015 processed in 0.59 seconds (time per batch)
# Processing batch 901/1015
# Batch 901/1015 processed in 0.59 seconds (time per batch)
# Processing batch 902/1015
# Batch 902/1015 processed in 0.59 seconds (time per batch)
# Processing batch 903/1015
# Batch 903/1015 processed in 0.59 seconds (time per batch)
# Processing batch 904/1015
# Batch 904/1015 processed in 0.59 seconds (time per batch)
# Processing batch 905/1015
# Batch 905/1015 processed in 0.59 seconds (time per batch)
# Processing batch 906/1015
# Batch 906/1015 processed in 0.59 seconds (time per batch)
# Processing batch 907/1015
# Batch 907/1015 processed in 0.59 seconds (time per batch)
# Processing batch 908/1015
# Batch 908/1015 processed in 0.59 seconds (time per batch)
# Processing batch 909/1015
# Batch 909/1015 processed in 0.59 seconds (time per batch)
# Processing batch 910/1015
# Batch 910/1015 processed in 0.58 seconds (time per batch)
# Processing batch 911/1015
# Batch 911/1015 processed in 0.59 seconds (time per batch)
# Processing batch 912/1015
# Batch 912/1015 processed in 0.58 seconds (time per batch)
# Processing batch 913/1015
# Batch 913/1015 processed in 0.59 seconds (time per batch)
# Processing batch 914/1015
# Batch 914/1015 processed in 0.59 seconds (time per batch)
# Processing batch 915/1015
# Batch 915/1015 processed in 0.59 seconds (time per batch)
# Processing batch 916/1015
# Batch 916/1015 processed in 0.58 seconds (time per batch)
# Processing batch 917/1015
# Batch 917/1015 processed in 0.59 seconds (time per batch)
# Processing batch 918/1015
# Batch 918/1015 processed in 0.59 seconds (time per batch)
# Processing batch 919/1015
# Batch 919/1015 processed in 0.59 seconds (time per batch)
# Processing batch 920/1015
# Batch 920/1015 processed in 0.58 seconds (time per batch)
# Processing batch 921/1015
# Batch 921/1015 processed in 0.59 seconds (time per batch)
# Processing batch 922/1015
# Batch 922/1015 processed in 0.59 seconds (time per batch)
# Processing batch 923/1015
# Batch 923/1015 processed in 0.59 seconds (time per batch)
# Processing batch 924/1015
# Batch 924/1015 processed in 0.59 seconds (time per batch)
# Processing batch 925/1015
# Batch 925/1015 processed in 0.59 seconds (time per batch)
# Processing batch 926/1015
# Batch 926/1015 processed in 0.58 seconds (time per batch)
# Processing batch 927/1015
# Batch 927/1015 processed in 0.59 seconds (time per batch)
# Processing batch 928/1015
# Batch 928/1015 processed in 0.58 seconds (time per batch)
# Processing batch 929/1015
# Batch 929/1015 processed in 0.59 seconds (time per batch)
# Processing batch 930/1015
# Batch 930/1015 processed in 0.58 seconds (time per batch)
# Processing batch 931/1015
# Batch 931/1015 processed in 0.59 seconds (time per batch)
# Processing batch 932/1015
# Batch 932/1015 processed in 0.58 seconds (time per batch)
# Processing batch 933/1015
# Batch 933/1015 processed in 0.58 seconds (time per batch)
# Processing batch 934/1015
# Batch 934/1015 processed in 0.59 seconds (time per batch)
# Processing batch 935/1015
# Batch 935/1015 processed in 0.59 seconds (time per batch)
# Processing batch 936/1015
# Batch 936/1015 processed in 0.59 seconds (time per batch)
# Processing batch 937/1015
# Batch 937/1015 processed in 0.59 seconds (time per batch)
# Processing batch 938/1015
# Batch 938/1015 processed in 0.59 seconds (time per batch)
# Processing batch 939/1015
# Batch 939/1015 processed in 0.59 seconds (time per batch)
# Processing batch 940/1015
# Batch 940/1015 processed in 0.59 seconds (time per batch)
# Processing batch 941/1015
# Batch 941/1015 processed in 0.59 seconds (time per batch)
# Processing batch 942/1015
# Batch 942/1015 processed in 0.59 seconds (time per batch)
# Processing batch 943/1015
# Batch 943/1015 processed in 0.59 seconds (time per batch)
# Processing batch 944/1015
# Batch 944/1015 processed in 0.58 seconds (time per batch)
# Processing batch 945/1015
# Batch 945/1015 processed in 0.59 seconds (time per batch)
# Processing batch 946/1015
# Batch 946/1015 processed in 0.59 seconds (time per batch)
# Processing batch 947/1015
# Batch 947/1015 processed in 0.59 seconds (time per batch)
# Processing batch 948/1015
# Batch 948/1015 processed in 0.59 seconds (time per batch)
# Processing batch 949/1015
# Batch 949/1015 processed in 0.59 seconds (time per batch)
# Processing batch 950/1015
# Batch 950/1015 processed in 0.58 seconds (time per batch)
# Processing batch 951/1015
# Batch 951/1015 processed in 0.58 seconds (time per batch)
# Processing batch 952/1015
# Batch 952/1015 processed in 0.59 seconds (time per batch)
# Processing batch 953/1015
# Batch 953/1015 processed in 0.58 seconds (time per batch)
# Processing batch 954/1015
# Batch 954/1015 processed in 0.58 seconds (time per batch)
# Processing batch 955/1015
# Batch 955/1015 processed in 0.58 seconds (time per batch)
# Processing batch 956/1015
# Batch 956/1015 processed in 0.59 seconds (time per batch)
# Processing batch 957/1015
# Batch 957/1015 processed in 0.58 seconds (time per batch)
# Processing batch 958/1015
# Batch 958/1015 processed in 0.59 seconds (time per batch)
# Processing batch 959/1015
# Batch 959/1015 processed in 0.59 seconds (time per batch)
# Processing batch 960/1015
# Batch 960/1015 processed in 0.59 seconds (time per batch)
# Processing batch 961/1015
# Batch 961/1015 processed in 0.59 seconds (time per batch)
# Processing batch 962/1015
# Batch 962/1015 processed in 0.59 seconds (time per batch)
# Processing batch 963/1015
# Batch 963/1015 processed in 0.58 seconds (time per batch)
# Processing batch 964/1015
# Batch 964/1015 processed in 0.59 seconds (time per batch)
# Processing batch 965/1015
# Batch 965/1015 processed in 0.59 seconds (time per batch)
# Processing batch 966/1015
# Batch 966/1015 processed in 0.59 seconds (time per batch)
# Processing batch 967/1015
# Batch 967/1015 processed in 0.59 seconds (time per batch)
# Processing batch 968/1015
# Batch 968/1015 processed in 0.59 seconds (time per batch)
# Processing batch 969/1015
# Batch 969/1015 processed in 0.59 seconds (time per batch)
# Processing batch 970/1015
# Batch 970/1015 processed in 0.59 seconds (time per batch)
# Processing batch 971/1015
# Batch 971/1015 processed in 0.58 seconds (time per batch)
# Processing batch 972/1015
# Batch 972/1015 processed in 0.58 seconds (time per batch)
# Processing batch 973/1015
# Batch 973/1015 processed in 0.59 seconds (time per batch)
# Processing batch 974/1015
# Batch 974/1015 processed in 0.59 seconds (time per batch)
# Processing batch 975/1015
# Batch 975/1015 processed in 0.58 seconds (time per batch)
# Processing batch 976/1015
# Batch 976/1015 processed in 0.59 seconds (time per batch)
# Processing batch 977/1015
# Batch 977/1015 processed in 0.58 seconds (time per batch)
# Processing batch 978/1015
# Batch 978/1015 processed in 0.59 seconds (time per batch)
# Processing batch 979/1015
# Batch 979/1015 processed in 0.59 seconds (time per batch)
# Processing batch 980/1015
# Batch 980/1015 processed in 0.59 seconds (time per batch)
# Processing batch 981/1015
# Batch 981/1015 processed in 0.59 seconds (time per batch)
# Processing batch 982/1015
# Batch 982/1015 processed in 0.59 seconds (time per batch)
# Processing batch 983/1015
# Batch 983/1015 processed in 0.59 seconds (time per batch)
# Processing batch 984/1015
# Batch 984/1015 processed in 0.59 seconds (time per batch)
# Processing batch 985/1015
# Batch 985/1015 processed in 0.59 seconds (time per batch)
# Processing batch 986/1015
# Batch 986/1015 processed in 0.58 seconds (time per batch)
# Processing batch 987/1015
# Batch 987/1015 processed in 0.59 seconds (time per batch)
# Processing batch 988/1015
# Batch 988/1015 processed in 0.59 seconds (time per batch)
# Processing batch 989/1015
# Batch 989/1015 processed in 0.59 seconds (time per batch)
# Processing batch 990/1015
# Batch 990/1015 processed in 0.59 seconds (time per batch)
# Processing batch 991/1015
# Batch 991/1015 processed in 0.59 seconds (time per batch)
# Processing batch 992/1015
# Batch 992/1015 processed in 0.59 seconds (time per batch)
# Processing batch 993/1015
# Batch 993/1015 processed in 0.58 seconds (time per batch)
# Processing batch 994/1015
# Batch 994/1015 processed in 0.58 seconds (time per batch)
# Processing batch 995/1015
# Batch 995/1015 processed in 0.59 seconds (time per batch)
# Processing batch 996/1015
# Batch 996/1015 processed in 0.58 seconds (time per batch)
# Processing batch 997/1015
# Batch 997/1015 processed in 0.58 seconds (time per batch)
# Processing batch 998/1015
# Batch 998/1015 processed in 0.59 seconds (time per batch)
# Processing batch 999/1015
# Batch 999/1015 processed in 0.59 seconds (time per batch)
# Processing batch 1000/1015
# Batch 1000/1015 processed in 0.59 seconds (time per batch)
# Processing batch 1001/1015
# Batch 1001/1015 processed in 0.59 seconds (time per batch)
# Processing batch 1002/1015
# Batch 1002/1015 processed in 0.59 seconds (time per batch)
# Processing batch 1003/1015
# Batch 1003/1015 processed in 0.59 seconds (time per batch)
# Processing batch 1004/1015
# Batch 1004/1015 processed in 0.58 seconds (time per batch)
# Processing batch 1005/1015
# Batch 1005/1015 processed in 0.58 seconds (time per batch)
# Processing batch 1006/1015
# Batch 1006/1015 processed in 0.59 seconds (time per batch)
# Processing batch 1007/1015
# Batch 1007/1015 processed in 0.59 seconds (time per batch)
# Processing batch 1008/1015
# Batch 1008/1015 processed in 0.59 seconds (time per batch)
# Processing batch 1009/1015
# Batch 1009/1015 processed in 0.59 seconds (time per batch)
# Processing batch 1010/1015
# Batch 1010/1015 processed in 0.59 seconds (time per batch)
# Processing batch 1011/1015
# Batch 1011/1015 processed in 0.59 seconds (time per batch)
# Processing batch 1012/1015
# Batch 1012/1015 processed in 0.58 seconds (time per batch)
# Processing batch 1013/1015
# Batch 1013/1015 processed in 0.59 seconds (time per batch)
# Processing batch 1014/1015
# Batch 1014/1015 processed in 0.59 seconds (time per batch)
# Processing batch 1015/1015
# Batch 1015/1015 processed in 0.51 seconds (time per batch)
# Run time statistics:
# Average time per batch: 0.59 seconds
# Total time: 593.91 seconds
# [0.5958092212677002, 0.5817956924438477, 0.5833971500396729, 0.582291841506958, 0.5823431015014648, 0.5826005935668945, 0.5824723243713379, 0.5840835571289062, 0.5845663547515869, 0.5842928886413574, 0.5841965675354004, 0.5839519500732422, 0.5838825702667236, 0.5838634967803955, 0.5835933685302734, 0.5849149227142334, 0.5839223861694336, 0.5840485095977783, 0.5839524269104004, 0.584275484085083, 0.5838356018066406, 0.5833168029785156, 0.583728551864624, 0.5836789608001709, 0.5854215621948242, 0.5836548805236816, 0.5843837261199951, 0.5844714641571045, 0.5839052200317383, 0.5849974155426025, 0.5841116905212402, 0.5841960906982422, 0.5844509601593018, 0.5840551853179932, 0.5850493907928467, 0.5844113826751709, 0.5835866928100586, 0.585075855255127, 0.5834994316101074, 0.5847501754760742, 0.5839254856109619, 0.584740161895752, 0.584280252456665, 0.5837149620056152, 0.5843207836151123, 0.584712028503418, 0.5846409797668457, 0.5849730968475342, 0.5841777324676514, 0.5843977928161621, 0.5847339630126953, 0.5842239856719971, 0.5850536823272705, 0.5845959186553955, 0.5853567123413086, 0.5841500759124756, 0.5843884944915771, 0.5849661827087402, 0.5847311019897461, 0.5852456092834473, 0.5850467681884766, 0.584909200668335, 0.5843651294708252, 0.5842373371124268, 0.5849695205688477, 0.585477352142334, 0.5850913524627686, 0.5847282409667969, 0.5844287872314453, 0.585085391998291, 0.5842530727386475, 0.5843620300292969, 0.5849268436431885, 0.5844993591308594, 0.584270715713501, 0.586118221282959, 0.5854933261871338, 0.5847988128662109, 0.5848672389984131, 0.5844297409057617, 0.5850827693939209, 0.5855200290679932, 0.5848686695098877, 0.5847208499908447, 0.5852127075195312, 0.5841255187988281, 0.5847408771514893, 0.5852255821228027, 0.5850715637207031, 0.5852479934692383, 0.5854544639587402, 0.5845563411712646, 0.5849313735961914, 0.5858633518218994, 0.5849332809448242, 0.584465742111206, 0.5853416919708252, 0.5850822925567627, 0.5846500396728516, 0.5856826305389404, 0.5848312377929688, 0.58620285987854, 0.5849542617797852, 0.5852024555206299, 0.5860292911529541, 0.5851454734802246, 0.5849237442016602, 0.5847470760345459, 0.5845131874084473, 0.585956335067749, 0.5850555896759033, 0.5859999656677246, 0.5856125354766846, 0.5846037864685059, 0.5847280025482178, 0.5851573944091797, 0.5854699611663818, 0.584773063659668, 0.586040735244751, 0.585299015045166, 0.5848567485809326, 0.5850276947021484, 0.5845708847045898, 0.5846545696258545, 0.5845792293548584, 0.5843255519866943, 0.5843193531036377, 0.5853378772735596, 0.5853748321533203, 0.5851619243621826, 0.585381031036377, 0.5851216316223145, 0.5848100185394287, 0.5850090980529785, 0.58467698097229, 0.5859348773956299, 0.5859355926513672, 0.5855944156646729, 0.5847780704498291, 0.5856668949127197, 0.5854289531707764, 0.5846798419952393, 0.5848956108093262, 0.5847342014312744, 0.5857586860656738, 0.586266279220581, 0.5852124691009521, 0.5849323272705078, 0.5852289199829102, 0.5856690406799316, 0.5852184295654297, 0.5850315093994141, 0.585618257522583, 0.5851426124572754, 0.5854971408843994, 0.5853044986724854, 0.584463357925415, 0.58457350730896, 0.5850913524627686, 0.5853445529937744, 0.5853650569915771, 0.5860176086425781, 0.584434986114502, 0.5853943824768066, 0.5851964950561523, 0.5856401920318604, 0.585587739944458, 0.5854203701019287, 0.58512282371521, 0.5859713554382324, 0.584979772567749, 0.5856034755706787, 0.5851249694824219, 0.5851342678070068, 0.5841367244720459, 0.5844666957855225, 0.5853903293609619, 0.584937572479248, 0.5857579708099365, 0.5874793529510498, 0.5854504108428955, 0.5855295658111572, 0.5852694511413574, 0.5857224464416504, 0.5851821899414062, 0.5853848457336426, 0.5854732990264893, 0.585120439529419, 0.5850241184234619, 0.5846641063690186, 0.5850679874420166, 0.584580659866333, 0.5850710868835449, 0.5845253467559814, 0.5849945545196533, 0.5869951248168945, 0.585533618927002, 0.5850670337677002, 0.5847756862640381, 0.5856754779815674, 0.5853261947631836, 0.5847291946411 ...
# Features extracted and saved for model: bert-cased

# %%
print(dt.Duration.astype(float).value_counts()[:20])
# Out:
# 30.0     8233
# 45.0     4303
# 360.0    4135
# 29.0     3769
# 60.0     2728
#          ...
# 84.0      102
# 99.0      101
# 300.0     101
# 95.0      100
# 20.0       99
# Name: Duration, Length: 64, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt

def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""
    n = len(data)
    x = np.sort(data)
    y = np.arange(1, n + 1) / n
    return x, y

# Example usage:
durations = dt['Duration'].astype(float)
x, y = ecdf(durations)
plt.plot(x, y, marker='.', linestyle='none')
plt.xlabel('Duration')
plt.ylabel('ECDF')
plt.show()

# %%
import pandas as pd

def print_percentile_table(data):
    percentiles = range(1, 101)
    values = [np.percentile(data, p) for p in percentiles]

    percentile_table = pd.DataFrame({
        'Percentile': percentiles,
        'Value': values
    })

    print(percentile_table)

# Example usage:
durations = dt['Duration'].astype(float)
print_percentile_table(durations)
# Out:
#     Percentile   Value
# 0            1   15.00
# 1            2   15.00
# 2            3   15.00
# 3            4   15.00
# 4            5   25.00
# ..         ...     ...
# 95          96  360.00
# 96          97  360.00
# 97          98  360.00
# 98          99  416.87
# 99         100  720.00
#
# [100 rows x 2 columns]

# %%
# !pip install sentencepiece

# %%
import numpy as np

def extract_and_save_features(texts, model_name):
    # Extract features
    features,times = extract_features(texts, model_name)
    
    print(times)
    
    # Save features to disk
    np.save(f'{model_name}_features.npy', features)

    print(f"Features extracted and saved for model: {model_name}")
    del features

# Define the list of model names
# model_names = ['bert', 'gpt2', 'roberta', 'mt5', 'xlnet','xlnet-large']
model_names = ['bert-large']
# For each model, extract and save features
for model_name in model_names:
    print(model_name)
    extract_and_save_features(dt.FullText, model_name)
# Out:
# bert-large
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.25G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Processing batch 1/762
# Batch 1/762 processed in 14.49 seconds (time per batch)
# Processing batch 2/762
# Batch 2/762 processed in 12.24 seconds (time per batch)
# Processing batch 3/762
# Batch 3/762 processed in 12.72 seconds (time per batch)
# Processing batch 4/762
# Batch 4/762 processed in 12.34 seconds (time per batch)
# Processing batch 5/762
# Batch 5/762 processed in 14.15 seconds (time per batch)
# Processing batch 6/762
# Batch 6/762 processed in 15.31 seconds (time per batch)
# Processing batch 7/762
# Batch 7/762 processed in 12.24 seconds (time per batch)
# Processing batch 8/762
# Batch 8/762 processed in 11.99 seconds (time per batch)
# Processing batch 9/762
# Batch 9/762 processed in 12.69 seconds (time per batch)
# Processing batch 10/762
# Batch 10/762 processed in 11.99 seconds (time per batch)
# Processing batch 11/762
# Batch 11/762 processed in 11.63 seconds (time per batch)
# Processing batch 12/762
# Batch 12/762 processed in 12.00 seconds (time per batch)
# Processing batch 13/762
# Batch 13/762 processed in 11.59 seconds (time per batch)
# Processing batch 14/762
# Batch 14/762 processed in 12.46 seconds (time per batch)
# Processing batch 15/762
# Batch 15/762 processed in 12.23 seconds (time per batch)
# Processing batch 16/762
# Batch 16/762 processed in 11.70 seconds (time per batch)
# Processing batch 17/762
# Batch 17/762 processed in 11.77 seconds (time per batch)
# Processing batch 18/762
# Batch 18/762 processed in 11.77 seconds (time per batch)
# Processing batch 19/762
# Batch 19/762 processed in 12.51 seconds (time per batch)
# Processing batch 20/762
# Batch 20/762 processed in 12.11 seconds (time per batch)
# Processing batch 21/762
# Batch 21/762 processed in 12.08 seconds (time per batch)
# Processing batch 22/762
# Batch 22/762 processed in 12.08 seconds (time per batch)
# Processing batch 23/762
# Batch 23/762 processed in 11.72 seconds (time per batch)
# Processing batch 24/762
# Batch 24/762 processed in 12.65 seconds (time per batch)
# Processing batch 25/762
# Batch 25/762 processed in 12.09 seconds (time per batch)
# Processing batch 26/762
# Batch 26/762 processed in 12.03 seconds (time per batch)
# Processing batch 27/762
# Batch 27/762 processed in 11.92 seconds (time per batch)
# Processing batch 28/762
# Batch 28/762 processed in 12.37 seconds (time per batch)
# Processing batch 29/762
# Batch 29/762 processed in 12.39 seconds (time per batch)
# Processing batch 30/762
# Batch 30/762 processed in 12.04 seconds (time per batch)
# Processing batch 31/762
# Batch 31/762 processed in 12.18 seconds (time per batch)
# Processing batch 32/762
# Batch 32/762 processed in 12.06 seconds (time per batch)
# Processing batch 33/762
# Batch 33/762 processed in 12.26 seconds (time per batch)
# Processing batch 34/762
# Batch 34/762 processed in 12.33 seconds (time per batch)
# Processing batch 35/762
# Batch 35/762 processed in 11.76 seconds (time per batch)
# Processing batch 36/762
# Batch 36/762 processed in 12.15 seconds (time per batch)
# Processing batch 37/762
# Batch 37/762 processed in 11.98 seconds (time per batch)
# Processing batch 38/762
# Batch 38/762 processed in 12.38 seconds (time per batch)
# Processing batch 39/762
# Batch 39/762 processed in 12.11 seconds (time per batch)
# Processing batch 40/762
# Batch 40/762 processed in 12.46 seconds (time per batch)
# Processing batch 41/762
# Batch 41/762 processed in 11.95 seconds (time per batch)
# Processing batch 42/762
# Batch 42/762 processed in 12.17 seconds (time per batch)
# Processing batch 43/762
# Batch 43/762 processed in 11.99 seconds (time per batch)
# Processing batch 44/762
# Batch 44/762 processed in 11.69 seconds (time per batch)
# Processing batch 45/762
# Batch 45/762 processed in 12.33 seconds (time per batch)
# Processing batch 46/762
# Batch 46/762 processed in 12.55 seconds (time per batch)
# Processing batch 47/762
# Batch 47/762 processed in 12.51 seconds (time per batch)
# Processing batch 48/762
# Batch 48/762 processed in 11.88 seconds (time per batch)
# Processing batch 49/762
# Batch 49/762 processed in 12.15 seconds (time per batch)
# Processing batch 50/762
# Batch 50/762 processed in 11.95 seconds (time per batch)
# Processing batch 51/762
# Batch 51/762 processed in 12.40 seconds (time per batch)
# Processing batch 52/762
# Batch 52/762 processed in 12.42 seconds (time per batch)
# Processing batch 53/762
# Batch 53/762 processed in 12.48 seconds (time per batch)
# Processing batch 54/762
# Batch 54/762 processed in 11.60 seconds (time per batch)
# Processing batch 55/762
# Batch 55/762 processed in 11.85 seconds (time per batch)
# Processing batch 56/762
# Batch 56/762 processed in 11.95 seconds (time per batch)
# Processing batch 57/762
# Batch 57/762 processed in 12.00 seconds (time per batch)
# Processing batch 58/762
# Batch 58/762 processed in 12.53 seconds (time per batch)
# Processing batch 59/762
# Batch 59/762 processed in 12.01 seconds (time per batch)
# Processing batch 60/762
# Batch 60/762 processed in 11.91 seconds (time per batch)
# Processing batch 61/762
# Batch 61/762 processed in 12.10 seconds (time per batch)
# Processing batch 62/762
# Batch 62/762 processed in 12.02 seconds (time per batch)
# Processing batch 63/762
# Batch 63/762 processed in 12.55 seconds (time per batch)
# Processing batch 64/762
# Batch 64/762 processed in 11.95 seconds (time per batch)
# Processing batch 65/762
# Batch 65/762 processed in 11.88 seconds (time per batch)
# Processing batch 66/762
# Batch 66/762 processed in 12.22 seconds (time per batch)
# Processing batch 67/762
# Batch 67/762 processed in 11.80 seconds (time per batch)
# Processing batch 68/762
# Batch 68/762 processed in 12.89 seconds (time per batch)
# Processing batch 69/762
# Batch 69/762 processed in 12.18 seconds (time per batch)
# Processing batch 70/762
# Batch 70/762 processed in 11.77 seconds (time per batch)
# Processing batch 71/762
# Batch 71/762 processed in 11.79 seconds (time per batch)
# Processing batch 72/762
# Batch 72/762 processed in 12.33 seconds (time per batch)
# Processing batch 73/762
# Batch 73/762 processed in 12.08 seconds (time per batch)
# Processing batch 74/762
# Batch 74/762 processed in 12.26 seconds (time per batch)
# Processing batch 75/762
# Batch 75/762 processed in 11.96 seconds (time per batch)
# Processing batch 76/762
# Batch 76/762 processed in 12.10 seconds (time per batch)
# Processing batch 77/762
# Batch 77/762 processed in 11.74 seconds (time per batch)
# Processing batch 78/762
# Batch 78/762 processed in 12.34 seconds (time per batch)
# Processing batch 79/762
# Batch 79/762 processed in 11.75 seconds (time per batch)
# Processing batch 80/762
# Batch 80/762 processed in 11.92 seconds (time per batch)
# Processing batch 81/762
# Batch 81/762 processed in 12.02 seconds (time per batch)
# Processing batch 82/762
# Batch 82/762 processed in 12.38 seconds (time per batch)
# Processing batch 83/762
# Batch 83/762 processed in 12.21 seconds (time per batch)
# Processing batch 84/762
# Batch 84/762 processed in 15.03 seconds (time per batch)
# Processing batch 85/762
# Batch 85/762 processed in 11.78 seconds (time per batch)
# Processing batch 86/762
# Batch 86/762 processed in 12.20 seconds (time per batch)
# Processing batch 87/762
# Batch 87/762 processed in 12.11 seconds (time per batch)
# Processing batch 88/762
# Batch 88/762 processed in 12.97 seconds (time per batch)
# Processing batch 89/762
# Batch 89/762 processed in 12.61 seconds (time per batch)
# Processing batch 90/762
# Batch 90/762 processed in 13.76 seconds (time per batch)
# Processing batch 91/762
# Batch 91/762 processed in 12.61 seconds (time per batch)
# Processing batch 92/762
# Batch 92/762 processed in 12.56 seconds (time per batch)
# Processing batch 93/762
# Batch 93/762 processed in 12.58 seconds (time per batch)
# Processing batch 94/762
# Batch 94/762 processed in 12.84 seconds (time per batch)
# Processing batch 95/762
# Batch 95/762 processed in 12.10 seconds (time per batch)
# Processing batch 96/762
# Batch 96/762 processed in 12.19 seconds (time per batch)
# Processing batch 97/762
# Batch 97/762 processed in 13.01 seconds (time per batch)
# Processing batch 98/762
# Batch 98/762 processed in 12.13 seconds (time per batch)
# Processing batch 99/762
# Batch 99/762 processed in 12.24 seconds (time per batch)
# Processing batch 100/762
# Batch 100/762 processed in 11.76 seconds (time per batch)
# Processing batch 101/762
# Batch 101/762 processed in 12.19 seconds (time per batch)
# Processing batch 102/762
# Batch 102/762 processed in 12.47 seconds (time per batch)
# Processing batch 103/762
# Batch 103/762 processed in 11.86 seconds (time per batch)
# Processing batch 104/762
# Batch 104/762 processed in 12.12 seconds (time per batch)
# Processing batch 105/762
# Batch 105/762 processed in 11.93 seconds (time per batch)
# Processing batch 106/762
# Batch 106/762 processed in 11.86 seconds (time per batch)
# Processing batch 107/762
# Batch 107/762 processed in 12.34 seconds (time per batch)
# Processing batch 108/762
# Batch 108/762 processed in 12.49 seconds (time per batch)
# Processing batch 109/762
# Batch 109/762 processed in 12.35 seconds (time per batch)
# Processing batch 110/762
# Batch 110/762 processed in 12.07 seconds (time per batch)
# Processing batch 111/762
# Batch 111/762 processed in 12.23 seconds (time per batch)
# Processing batch 112/762
# Batch 112/762 processed in 12.04 seconds (time per batch)
# Processing batch 113/762
# Batch 113/762 processed in 12.52 seconds (time per batch)
# Processing batch 114/762
# Batch 114/762 processed in 12.14 seconds (time per batch)
# Processing batch 115/762
# Batch 115/762 processed in 11.70 seconds (time per batch)
# Processing batch 116/762
# Batch 116/762 processed in 12.77 seconds (time per batch)
# Processing batch 117/762
# Batch 117/762 processed in 12.29 seconds (time per batch)
# Processing batch 118/762
# Batch 118/762 processed in 12.17 seconds (time per batch)
# Processing batch 119/762
# Batch 119/762 processed in 11.80 seconds (time per batch)
# Processing batch 120/762
# Batch 120/762 processed in 11.87 seconds (time per batch)
# Processing batch 121/762
# Batch 121/762 processed in 12.18 seconds (time per batch)
# Processing batch 122/762
# Batch 122/762 processed in 12.37 seconds (time per batch)
# Processing batch 123/762
# Batch 123/762 processed in 12.29 seconds (time per batch)
# Processing batch 124/762
# Batch 124/762 processed in 11.59 seconds (time per batch)
# Processing batch 125/762
# Batch 125/762 processed in 11.98 seconds (time per batch)
# Processing batch 126/762
# Batch 126/762 processed in 11.98 seconds (time per batch)
# Processing batch 127/762
# Batch 127/762 processed in 13.09 seconds (time per batch)
# Processing batch 128/762
# Batch 128/762 processed in 11.87 seconds (time per batch)
# Processing batch 129/762
# Batch 129/762 processed in 11.53 seconds (time per batch)
# Processing batch 130/762
# Batch 130/762 processed in 13.20 seconds (time per batch)
# Processing batch 131/762
# Batch 131/762 processed in 11.99 seconds (time per batch)
# Processing batch 132/762
# Batch 132/762 processed in 13.27 seconds (time per batch)
# Processing batch 133/762
# Batch 133/762 processed in 12.02 seconds (time per batch)
# Processing batch 134/762
# Batch 134/762 processed in 12.26 seconds (time per batch)
# Processing batch 135/762
# Batch 135/762 processed in 11.50 seconds (time per batch)
# Processing batch 136/762
# Batch 136/762 processed in 11.67 seconds (time per batch)
# Processing batch 137/762
# Batch 137/762 processed in 13.23 seconds (time per batch)
# Processing batch 138/762
# Batch 138/762 processed in 12.04 seconds (time per batch)
# Processing batch 139/762
# Batch 139/762 processed in 11.93 seconds (time per batch)
# Processing batch 140/762
# Batch 140/762 processed in 11.83 seconds (time per batch)
# Processing batch 141/762
# Batch 141/762 processed in 12.06 seconds (time per batch)
# Processing batch 142/762
# Batch 142/762 processed in 12.66 seconds (time per batch)
# Processing batch 143/762
# Batch 143/762 processed in 12.14 seconds (time per batch)
# Processing batch 144/762
# Batch 144/762 processed in 12.06 seconds (time per batch)
# Processing batch 145/762
# Batch 145/762 processed in 12.24 seconds (time per batch)
# Processing batch 146/762
# Batch 146/762 processed in 11.87 seconds (time per batch)
# Processing batch 147/762
# Batch 147/762 processed in 12.57 seconds (time per batch)
# Processing batch 148/762
# Batch 148/762 processed in 12.26 seconds (time per batch)
# Processing batch 149/762
# Batch 149/762 processed in 11.92 seconds (time per batch)
# Processing batch 150/762
# Batch 150/762 processed in 12.42 seconds (time per batch)
# Processing batch 151/762
# Batch 151/762 processed in 12.86 seconds (time per batch)
# Processing batch 152/762
# Batch 152/762 processed in 12.56 seconds (time per batch)
# Processing batch 153/762
# Batch 153/762 processed in 12.28 seconds (time per batch)
# Processing batch 154/762
# Batch 154/762 processed in 11.96 seconds (time per batch)
# Processing batch 155/762
# Batch 155/762 processed in 11.71 seconds (time per batch)
# Processing batch 156/762
# Batch 156/762 processed in 12.02 seconds (time per batch)
# Processing batch 157/762
# Batch 157/762 processed in 12.05 seconds (time per batch)
# Processing batch 158/762
# Batch 158/762 processed in 12.11 seconds (time per batch)
# Processing batch 159/762
# Batch 159/762 processed in 11.56 seconds (time per batch)
# Processing batch 160/762
# Batch 160/762 processed in 12.23 seconds (time per batch)
# Processing batch 161/762
# Batch 161/762 processed in 12.07 seconds (time per batch)
# Processing batch 162/762
# Batch 162/762 processed in 12.27 seconds (time per batch)
# Processing batch 163/762
# Batch 163/762 processed in 11.86 seconds (time per batch)
# Processing batch 164/762
# Batch 164/762 processed in 12.09 seconds (time per batch)
# Processing batch 165/762
# Batch 165/762 processed in 12.42 seconds (time per batch)
# Processing batch 166/762
# Batch 166/762 processed in 12.30 seconds (time per batch)
# Processing batch 167/762
# Batch 167/762 processed in 12.18 seconds (time per batch)
# Processing batch 168/762
# Batch 168/762 processed in 11.94 seconds (time per batch)
# Processing batch 169/762
# Batch 169/762 processed in 12.39 seconds (time per batch)
# Processing batch 170/762
# Batch 170/762 processed in 12.34 seconds (time per batch)
# Processing batch 171/762
# Batch 171/762 processed in 13.08 seconds (time per batch)
# Processing batch 172/762
# Batch 172/762 processed in 12.00 seconds (time per batch)
# Processing batch 173/762
# Batch 173/762 processed in 12.48 seconds (time per batch)
# Processing batch 174/762
# Batch 174/762 processed in 11.63 seconds (time per batch)
# Processing batch 175/762
# Batch 175/762 processed in 11.96 seconds (time per batch)
# Processing batch 176/762
# Batch 176/762 processed in 12.52 seconds (time per batch)
# Processing batch 177/762
# Batch 177/762 processed in 11.71 seconds (time per batch)
# Processing batch 178/762
# Batch 178/762 processed in 11.95 seconds (time per batch)
# Processing batch 179/762
# Batch 179/762 processed in 11.88 seconds (time per batch)
# Processing batch 180/762
# Batch 180/762 processed in 12.38 seconds (time per batch)
# Processing batch 181/762
# Batch 181/762 processed in 13.80 seconds (time per batch)
# Processing batch 182/762
# Batch 182/762 processed in 11.93 seconds (time per batch)
# Processing batch 183/762
# Batch 183/762 processed in 11.47 seconds (time per batch)
# Processing batch 184/762
# Batch 184/762 processed in 11.98 seconds (time per batch)
# Processing batch 185/762
# Batch 185/762 processed in 11.63 seconds (time per batch)
# Processing batch 186/762
# Batch 186/762 processed in 12.17 seconds (time per batch)
# Processing batch 187/762
# Batch 187/762 processed in 11.98 seconds (time per batch)
# Processing batch 188/762
# Batch 188/762 processed in 11.25 seconds (time per batch)
# Processing batch 189/762
# Batch 189/762 processed in 12.02 seconds (time per batch)
# Processing batch 190/762
# Batch 190/762 processed in 12.34 seconds (time per batch)
# Processing batch 191/762
# Batch 191/762 processed in 11.98 seconds (time per batch)
# Processing batch 192/762
# Batch 192/762 processed in 11.60 seconds (time per batch)
# Processing batch 193/762
# Batch 193/762 processed in 11.44 seconds (time per batch)
# Processing batch 194/762
# Batch 194/762 processed in 11.55 seconds (time per batch)
# Processing batch 195/762
# Batch 195/762 processed in 11.80 seconds (time per batch)
# Processing batch 196/762
# Batch 196/762 processed in 11.95 seconds (time per batch)
# Processing batch 197/762
# Batch 197/762 processed in 11.73 seconds (time per batch)
# Processing batch 198/762
# Batch 198/762 processed in 11.79 seconds (time per batch)
# Processing batch 199/762
# Batch 199/762 processed in 12.48 seconds (time per batch)
# Processing batch 200/762
# Batch 200/762 processed in 12.19 seconds (time per batch)
# Processing batch 201/762
# Batch 201/762 processed in 11.94 seconds (time per batch)
# Processing batch 202/762
# Batch 202/762 processed in 11.99 seconds (time per batch)
# Processing batch 203/762
# Batch 203/762 processed in 12.25 seconds (time per batch)
# Processing batch 204/762
# Batch 204/762 processed in 12.27 seconds (time per batch)
# Processing batch 205/762
# Batch 205/762 processed in 12.04 seconds (time per batch)
# Processing batch 206/762
# Batch 206/762 processed in 12.17 seconds (time per batch)
# Processing batch 207/762
# Batch 207/762 processed in 11.68 seconds (time per batch)
# Processing batch 208/762
# Batch 208/762 processed in 11.96 seconds (time per batch)
# Processing batch 209/762
# Batch 209/762 processed in 11.99 seconds (time per batch)
# Processing batch 210/762
# Batch 210/762 processed in 11.96 seconds (time per batch)
# Processing batch 211/762
# Batch 211/762 processed in 12.34 seconds (time per batch)
# Processing batch 212/762
# Batch 212/762 processed in 11.67 seconds (time per batch)
# Processing batch 213/762
# Batch 213/762 processed in 11.98 seconds (time per batch)
# Processing batch 214/762
# Batch 214/762 processed in 12.00 seconds (time per batch)
# Processing batch 215/762
# Batch 215/762 processed in 11.68 seconds (time per batch)
# Processing batch 216/762
# Batch 216/762 processed in 12.27 seconds (time per batch)
# Processing batch 217/762
# Batch 217/762 processed in 11.78 seconds (time per batch)
# Processing batch 218/762
# Batch 218/762 processed in 12.18 seconds (time per batch)
# Processing batch 219/762
# Batch 219/762 processed in 11.76 seconds (time per batch)
# Processing batch 220/762
# Batch 220/762 processed in 12.24 seconds (time per batch)
# Processing batch 221/762
# Batch 221/762 processed in 12.11 seconds (time per batch)
# Processing batch 222/762
# Batch 222/762 processed in 11.56 seconds (time per batch)
# Processing batch 223/762
# Batch 223/762 processed in 11.83 seconds (time per batch)
# Processing batch 224/762
# Batch 224/762 processed in 11.56 seconds (time per batch)
# Processing batch 225/762
# Batch 225/762 processed in 11.70 seconds (time per batch)
# Processing batch 226/762
# Batch 226/762 processed in 12.15 seconds (time per batch)
# Processing batch 227/762
# Batch 227/762 processed in 11.73 seconds (time per batch)
# Processing batch 228/762
# Batch 228/762 processed in 11.81 seconds (time per batch)
# Processing batch 229/762
# Batch 229/762 processed in 11.95 seconds (time per batch)
# Processing batch 230/762
# Batch 230/762 processed in 11.94 seconds (time per batch)
# Processing batch 231/762
# Batch 231/762 processed in 12.68 seconds (time per batch)
# Processing batch 232/762
# Batch 232/762 processed in 11.91 seconds (time per batch)
# Processing batch 233/762
# Batch 233/762 processed in 11.50 seconds (time per batch)
# Processing batch 234/762
# Batch 234/762 processed in 11.77 seconds (time per batch)
# Processing batch 235/762
# Batch 235/762 processed in 11.71 seconds (time per batch)
# Processing batch 236/762
# Batch 236/762 processed in 12.24 seconds (time per batch)
# Processing batch 237/762
# Batch 237/762 processed in 11.85 seconds (time per batch)
# Processing batch 238/762
# Batch 238/762 processed in 11.58 seconds (time per batch)
# Processing batch 239/762
# Batch 239/762 processed in 13.65 seconds (time per batch)
# Processing batch 240/762
# Batch 240/762 processed in 12.34 seconds (time per batch)
# Processing batch 241/762
# Batch 241/762 processed in 11.93 seconds (time per batch)
# Processing batch 242/762
# Batch 242/762 processed in 12.40 seconds (time per batch)
# Processing batch 243/762
# Batch 243/762 processed in 12.15 seconds (time per batch)
# Processing batch 244/762
# Batch 244/762 processed in 11.93 seconds (time per batch)
# Processing batch 245/762
# Batch 245/762 processed in 11.26 seconds (time per batch)
# Processing batch 246/762
# Batch 246/762 processed in 12.20 seconds (time per batch)
# Processing batch 247/762
# Batch 247/762 processed in 11.68 seconds (time per batch)
# Processing batch 248/762
# Batch 248/762 processed in 11.54 seconds (time per batch)
# Processing batch 249/762
# Batch 249/762 processed in 12.02 seconds (time per batch)
# Processing batch 250/762
# Batch 250/762 processed in 12.32 seconds (time per batch)
# Processing batch 251/762
# Batch 251/762 processed in 12.15 seconds (time per batch)
# Processing batch 252/762
# Batch 252/762 processed in 11.41 seconds (time per batch)
# Processing batch 253/762
# Batch 253/762 processed in 12.09 seconds (time per batch)
# Processing batch 254/762
# Batch 254/762 processed in 11.82 seconds (time per batch)
# Processing batch 255/762
# Batch 255/762 processed in 11.70 seconds (time per batch)
# Processing batch 256/762
# Batch 256/762 processed in 12.24 seconds (time per batch)
# Processing batch 257/762
# Batch 257/762 processed in 11.96 seconds (time per batch)
# Processing batch 258/762
# Batch 258/762 processed in 12.05 seconds (time per batch)
# Processing batch 259/762
# Batch 259/762 processed in 12.14 seconds (time per batch)
# Processing batch 260/762
# Batch 260/762 processed in 12.04 seconds (time per batch)
# Processing batch 261/762
# Batch 261/762 processed in 12.26 seconds (time per batch)
# Processing batch 262/762
# Batch 262/762 processed in 11.63 seconds (time per batch)
# Processing batch 263/762
# Batch 263/762 processed in 12.00 seconds (time per batch)
# Processing batch 264/762
# Batch 264/762 processed in 12.03 seconds (time per batch)
# Processing batch 265/762
# Batch 265/762 processed in 11.80 seconds (time per batch)
# Processing batch 266/762
# Batch 266/762 processed in 12.21 seconds (time per batch)
# Processing batch 267/762
# Batch 267/762 processed in 11.79 seconds (time per batch)
# Processing batch 268/762
# Batch 268/762 processed in 12.15 seconds (time per batch)
# Processing batch 269/762
# Batch 269/762 processed in 12.10 seconds (time per batch)
# Processing batch 270/762
# Batch 270/762 processed in 11.77 seconds (time per batch)
# Processing batch 271/762
# Batch 271/762 processed in 11.93 seconds (time per batch)
# Processing batch 272/762
# Batch 272/762 processed in 11.66 seconds (time per batch)
# Processing batch 273/762
# Batch 273/762 processed in 12.04 seconds (time per batch)
# Processing batch 274/762
# Batch 274/762 processed in 12.23 seconds (time per batch)
# Processing batch 275/762
# Batch 275/762 processed in 12.02 seconds (time per batch)
# Processing batch 276/762
# Batch 276/762 processed in 12.02 seconds (time per batch)
# Processing batch 277/762
# Batch 277/762 processed in 12.30 seconds (time per batch)
# Processing batch 278/762
# Batch 278/762 processed in 12.35 seconds (time per batch)
# Processing batch 279/762
# Batch 279/762 processed in 11.51 seconds (time per batch)
# Processing batch 280/762
# Batch 280/762 processed in 12.30 seconds (time per batch)
# Processing batch 281/762
# Batch 281/762 processed in 12.17 seconds (time per batch)
# Processing batch 282/762
# Batch 282/762 processed in 11.44 seconds (time per batch)
# Processing batch 283/762
# Batch 283/762 processed in 11.56 seconds (time per batch)
# Processing batch 284/762
# Batch 284/762 processed in 11.41 seconds (time per batch)
# Processing batch 285/762
# Batch 285/762 processed in 11.61 seconds (time per batch)
# Processing batch 286/762
# Batch 286/762 processed in 12.36 seconds (time per batch)
# Processing batch 287/762
# Batch 287/762 processed in 11.92 seconds (time per batch)
# Processing batch 288/762
# Batch 288/762 processed in 13.43 seconds (time per batch)
# Processing batch 289/762
# Batch 289/762 processed in 12.75 seconds (time per batch)
# Processing batch 290/762
# Batch 290/762 processed in 11.73 seconds (time per batch)
# Processing batch 291/762
# Batch 291/762 processed in 12.19 seconds (time per batch)
# Processing batch 292/762
# Batch 292/762 processed in 12.51 seconds (time per batch)
# Processing batch 293/762
# Batch 293/762 processed in 11.23 seconds (time per batch)
# Processing batch 294/762
# Batch 294/762 processed in 11.37 seconds (time per batch)
# Processing batch 295/762
# Batch 295/762 processed in 11.42 seconds (time per batch)
# Processing batch 296/762
# Batch 296/762 processed in 11.79 seconds (time per batch)
# Processing batch 297/762
# Batch 297/762 processed in 11.04 seconds (time per batch)
# Processing batch 298/762
# Batch 298/762 processed in 11.03 seconds (time per batch)
# Processing batch 299/762
# Batch 299/762 processed in 11.20 seconds (time per batch)
# Processing batch 300/762
# Batch 300/762 processed in 11.37 seconds (time per batch)
# Processing batch 301/762
# Batch 301/762 processed in 11.31 seconds (time per batch)
# Processing batch 302/762
# Batch 302/762 processed in 11.68 seconds (time per batch)
# Processing batch 303/762
# Batch 303/762 processed in 11.16 seconds (time per batch)
# Processing batch 304/762
# Batch 304/762 processed in 10.88 seconds (time per batch)
# Processing batch 305/762
# Batch 305/762 processed in 11.24 seconds (time per batch)
# Processing batch 306/762
# Batch 306/762 processed in 12.01 seconds (time per batch)
# Processing batch 307/762
# Batch 307/762 processed in 11.55 seconds (time per batch)
# Processing batch 308/762
# Batch 308/762 processed in 12.07 seconds (time per batch)
# Processing batch 309/762
# Batch 309/762 processed in 11.86 seconds (time per batch)
# Processing batch 310/762
# Batch 310/762 processed in 11.13 seconds (time per batch)
# Processing batch 311/762
# Batch 311/762 processed in 11.45 seconds (time per batch)
# Processing batch 312/762
# Batch 312/762 processed in 11.94 seconds (time per batch)
# Processing batch 313/762
# Batch 313/762 processed in 11.57 seconds (time per batch)
# Processing batch 314/762
# Batch 314/762 processed in 11.23 seconds (time per batch)
# Processing batch 315/762
# Batch 315/762 processed in 11.14 seconds (time per batch)
# Processing batch 316/762
# Batch 316/762 processed in 12.26 seconds (time per batch)
# Processing batch 317/762
# Batch 317/762 processed in 12.67 seconds (time per batch)
# Processing batch 318/762
# Batch 318/762 processed in 11.80 seconds (time per batch)
# Processing batch 319/762
# Batch 319/762 processed in 10.85 seconds (time per batch)
# Processing batch 320/762
# Batch 320/762 processed in 11.14 seconds (time per batch)
# Processing batch 321/762
# Batch 321/762 processed in 11.40 seconds (time per batch)
# Processing batch 322/762
# Batch 322/762 processed in 12.01 seconds (time per batch)
# Processing batch 323/762
# Batch 323/762 processed in 11.39 seconds (time per batch)
# Processing batch 324/762
# Batch 324/762 processed in 11.16 seconds (time per batch)
# Processing batch 325/762
# Batch 325/762 processed in 11.26 seconds (time per batch)
# Processing batch 326/762
# Batch 326/762 processed in 11.08 seconds (time per batch)
# Processing batch 327/762
# Batch 327/762 processed in 12.07 seconds (time per batch)
# Processing batch 328/762
# Batch 328/762 processed in 11.96 seconds (time per batch)
# Processing batch 329/762
# Batch 329/762 processed in 11.17 seconds (time per batch)
# Processing batch 330/762
# Batch 330/762 processed in 11.22 seconds (time per batch)
# Processing batch 331/762
# Batch 331/762 processed in 11.24 seconds (time per batch)
# Processing batch 332/762
# Batch 332/762 processed in 11.29 seconds (time per batch)
# Processing batch 333/762
# Batch 333/762 processed in 11.36 seconds (time per batch)
# Processing batch 334/762
# Batch 334/762 processed in 11.78 seconds (time per batch)
# Processing batch 335/762
# Batch 335/762 processed in 12.14 seconds (time per batch)
# Processing batch 336/762
# Batch 336/762 processed in 11.02 seconds (time per batch)
# Processing batch 337/762
# Batch 337/762 processed in 11.39 seconds (time per batch)
# Processing batch 338/762
# Batch 338/762 processed in 11.54 seconds (time per batch)
# Processing batch 339/762
# Batch 339/762 processed in 11.41 seconds (time per batch)
# Processing batch 340/762
# Batch 340/762 processed in 10.92 seconds (time per batch)
# Processing batch 341/762
# Batch 341/762 processed in 11.32 seconds (time per batch)
# Processing batch 342/762
# Batch 342/762 processed in 11.76 seconds (time per batch)
# Processing batch 343/762
# Batch 343/762 processed in 11.40 seconds (time per batch)
# Processing batch 344/762
# Batch 344/762 processed in 11.06 seconds (time per batch)
# Processing batch 345/762
# Batch 345/762 processed in 11.51 seconds (time per batch)
# Processing batch 346/762
# Batch 346/762 processed in 11.34 seconds (time per batch)
# Processing batch 347/762
# Batch 347/762 processed in 10.94 seconds (time per batch)
# Processing batch 348/762
# Batch 348/762 processed in 11.69 seconds (time per batch)
# Processing batch 349/762
# Batch 349/762 processed in 11.34 seconds (time per batch)
# Processing batch 350/762
# Batch 350/762 processed in 11.38 seconds (time per batch)
# Processing batch 351/762
# Batch 351/762 processed in 11.25 seconds (time per batch)
# Processing batch 352/762
# Batch 352/762 processed in 11.52 seconds (time per batch)
# Processing batch 353/762
# Batch 353/762 processed in 11.39 seconds (time per batch)
# Processing batch 354/762
# Batch 354/762 processed in 11.61 seconds (time per batch)
# Processing batch 355/762
# Batch 355/762 processed in 11.27 seconds (time per batch)
# Processing batch 356/762
# Batch 356/762 processed in 11.03 seconds (time per batch)
# Processing batch 357/762
# Batch 357/762 processed in 11.95 seconds (time per batch)
# Processing batch 358/762
# Batch 358/762 processed in 10.97 seconds (time per batch)
# Processing batch 359/762
# Batch 359/762 processed in 11.71 seconds (time per batch)
# Processing batch 360/762
# Batch 360/762 processed in 11.41 seconds (time per batch)
# Processing batch 361/762
# Batch 361/762 processed in 10.75 seconds (time per batch)
# Processing batch 362/762
# Batch 362/762 processed in 10.95 seconds (time per batch)
# Processing batch 363/762
# Batch 363/762 processed in 11.16 seconds (time per batch)
# Processing batch 364/762
# Batch 364/762 processed in 11.21 seconds (time per batch)
# Processing batch 365/762
# Batch 365/762 processed in 11.96 seconds (time per batch)
# Processing batch 366/762
# Batch 366/762 processed in 10.95 seconds (time per batch)
# Processing batch 367/762
# Batch 367/762 processed in 10.99 seconds (time per batch)
# Processing batch 368/762
# Batch 368/762 processed in 11.04 seconds (time per batch)
# Processing batch 369/762
# Batch 369/762 processed in 11.18 seconds (time per batch)
# Processing batch 370/762
# Batch 370/762 processed in 11.52 seconds (time per batch)
# Processing batch 371/762
# Batch 371/762 processed in 10.91 seconds (time per batch)
# Processing batch 372/762
# Batch 372/762 processed in 11.17 seconds (time per batch)
# Processing batch 373/762
# Batch 373/762 processed in 11.00 seconds (time per batch)
# Processing batch 374/762
# Batch 374/762 processed in 11.56 seconds (time per batch)
# Processing batch 375/762
# Batch 375/762 processed in 11.43 seconds (time per batch)
# Processing batch 376/762
# Batch 376/762 processed in 11.40 seconds (time per batch)
# Processing batch 377/762
# Batch 377/762 processed in 11.27 seconds (time per batch)
# Processing batch 378/762
# Batch 378/762 processed in 11.07 seconds (time per batch)
# Processing batch 379/762
# Batch 379/762 processed in 11.70 seconds (time per batch)
# Processing batch 380/762
# Batch 380/762 processed in 11.19 seconds (time per batch)
# Processing batch 381/762
# Batch 381/762 processed in 11.00 seconds (time per batch)
# Processing batch 382/762
# Batch 382/762 processed in 11.58 seconds (time per batch)
# Processing batch 383/762
# Batch 383/762 processed in 11.32 seconds (time per batch)
# Processing batch 384/762
# Batch 384/762 processed in 11.24 seconds (time per batch)
# Processing batch 385/762
# Batch 385/762 processed in 11.12 seconds (time per batch)
# Processing batch 386/762
# Batch 386/762 processed in 11.79 seconds (time per batch)
# Processing batch 387/762
# Batch 387/762 processed in 11.68 seconds (time per batch)
# Processing batch 388/762
# Batch 388/762 processed in 10.94 seconds (time per batch)
# Processing batch 389/762
# Batch 389/762 processed in 11.00 seconds (time per batch)
# Processing batch 390/762
# Batch 390/762 processed in 11.14 seconds (time per batch)
# Processing batch 391/762
# Batch 391/762 processed in 11.76 seconds (time per batch)
# Processing batch 392/762
# Batch 392/762 processed in 11.19 seconds (time per batch)
# Processing batch 393/762
# Batch 393/762 processed in 12.30 seconds (time per batch)
# Processing batch 394/762
# Batch 394/762 processed in 11.17 seconds (time per batch)
# Processing batch 395/762
# Batch 395/762 processed in 11.13 seconds (time per batch)
# Processing batch 396/762
# Batch 396/762 processed in 11.15 seconds (time per batch)
# Processing batch 397/762
# Batch 397/762 processed in 11.12 seconds (time per batch)
# Processing batch 398/762
# Batch 398/762 processed in 11.45 seconds (time per batch)
# Processing batch 399/762
# Batch 399/762 processed in 11.25 seconds (time per batch)
# Processing batch 400/762
# Batch 400/762 processed in 11.26 seconds (time per batch)
# Processing batch 401/762
# Batch 401/762 processed in 11.04 seconds (time per batch)
# Processing batch 402/762
# Batch 402/762 processed in 11.66 seconds (time per batch)
# Processing batch 403/762
# Batch 403/762 processed in 10.88 seconds (time per batch)
# Processing batch 404/762
# Batch 404/762 processed in 11.02 seconds (time per batch)
# Processing batch 405/762
# Batch 405/762 processed in 11.49 seconds (time per batch)
# Processing batch 406/762
# Batch 406/762 processed in 11.59 seconds (time per batch)
# Processing batch 407/762
# Batch 407/762 processed in 11.44 seconds (time per batch)
# Processing batch 408/762
# Batch 408/762 processed in 11.17 seconds (time per batch)
# Processing batch 409/762
# Batch 409/762 processed in 10.86 seconds (time per batch)
# Processing batch 410/762
# Batch 410/762 processed in 11.19 seconds (time per batch)
# Processing batch 411/762
# Batch 411/762 processed in 11.03 seconds (time per batch)
# Processing batch 412/762
# Batch 412/762 processed in 11.21 seconds (time per batch)
# Processing batch 413/762
# Batch 413/762 processed in 11.11 seconds (time per batch)
# Processing batch 414/762
# Batch 414/762 processed in 11.50 seconds (time per batch)
# Processing batch 415/762
# Batch 415/762 processed in 11.41 seconds (time per batch)
# Processing batch 416/762
# Batch 416/762 processed in 12.67 seconds (time per batch)
# Processing batch 417/762
# Batch 417/762 processed in 11.62 seconds (time per batch)
# Processing batch 418/762
# Batch 418/762 processed in 11.09 seconds (time per batch)
# Processing batch 419/762
# Batch 419/762 processed in 11.06 seconds (time per batch)
# Processing batch 420/762
# Batch 420/762 processed in 11.81 seconds (time per batch)
# Processing batch 421/762
# Batch 421/762 processed in 11.02 seconds (time per batch)
# Processing batch 422/762
# Batch 422/762 processed in 11.05 seconds (time per batch)
# Processing batch 423/762
# Batch 423/762 processed in 11.83 seconds (time per batch)
# Processing batch 424/762
# Batch 424/762 processed in 10.93 seconds (time per batch)
# Processing batch 425/762
# Batch 425/762 processed in 11.14 seconds (time per batch)
# Processing batch 426/762
# Batch 426/762 processed in 11.21 seconds (time per batch)
# Processing batch 427/762
# Batch 427/762 processed in 11.19 seconds (time per batch)
# Processing batch 428/762
# Batch 428/762 processed in 11.29 seconds (time per batch)
# Processing batch 429/762
# Batch 429/762 processed in 11.52 seconds (time per batch)
# Processing batch 430/762
# Batch 430/762 processed in 10.83 seconds (time per batch)
# Processing batch 431/762
# Batch 431/762 processed in 10.88 seconds (time per batch)
# Processing batch 432/762
# Batch 432/762 processed in 10.88 seconds (time per batch)
# Processing batch 433/762
# Batch 433/762 processed in 10.99 seconds (time per batch)
# Processing batch 434/762
# Batch 434/762 processed in 12.60 seconds (time per batch)
# Processing batch 435/762
# Batch 435/762 processed in 11.09 seconds (time per batch)
# Processing batch 436/762
# Batch 436/762 processed in 11.23 seconds (time per batch)
# Processing batch 437/762
# Batch 437/762 processed in 11.14 seconds (time per batch)
# Processing batch 438/762
# Batch 438/762 processed in 11.39 seconds (time per batch)
# Processing batch 439/762
# Batch 439/762 processed in 11.52 seconds (time per batch)
# Processing batch 440/762
# Batch 440/762 processed in 11.11 seconds (time per batch)
# Processing batch 441/762
# Batch 441/762 processed in 12.02 seconds (time per batch)
# Processing batch 442/762
# Batch 442/762 processed in 11.08 seconds (time per batch)
# Processing batch 443/762
# Batch 443/762 processed in 11.00 seconds (time per batch)
# Processing batch 444/762
# Batch 444/762 processed in 11.37 seconds (time per batch)
# Processing batch 445/762
# Batch 445/762 processed in 11.01 seconds (time per batch)
# Processing batch 446/762
# Batch 446/762 processed in 10.89 seconds (time per batch)
# Processing batch 447/762
# Batch 447/762 processed in 11.17 seconds (time per batch)
# Processing batch 448/762
# Batch 448/762 processed in 11.47 seconds (time per batch)
# Processing batch 449/762
# Batch 449/762 processed in 10.95 seconds (time per batch)
# Processing batch 450/762
# Batch 450/762 processed in 11.09 seconds (time per batch)
# Processing batch 451/762
# Batch 451/762 processed in 11.23 seconds (time per batch)
# Processing batch 452/762
# Batch 452/762 processed in 12.04 seconds (time per batch)
# Processing batch 453/762
# Batch 453/762 processed in 11.41 seconds (time per batch)
# Processing batch 454/762
# Batch 454/762 processed in 11.25 seconds (time per batch)
# Processing batch 455/762
# Batch 455/762 processed in 11.44 seconds (time per batch)
# Processing batch 456/762
# Batch 456/762 processed in 11.72 seconds (time per batch)
# Processing batch 457/762
# Batch 457/762 processed in 12.04 seconds (time per batch)
# Processing batch 458/762
# Batch 458/762 processed in 11.09 seconds (time per batch)
# Processing batch 459/762
# Batch 459/762 processed in 11.83 seconds (time per batch)
# Processing batch 460/762
# Batch 460/762 processed in 11.35 seconds (time per batch)
# Processing batch 461/762
# Batch 461/762 processed in 11.35 seconds (time per batch)
# Processing batch 462/762
# Batch 462/762 processed in 12.38 seconds (time per batch)
# Processing batch 463/762
# Batch 463/762 processed in 11.20 seconds (time per batch)
# Processing batch 464/762
# Batch 464/762 processed in 11.48 seconds (time per batch)
# Processing batch 465/762
# Batch 465/762 processed in 11.51 seconds (time per batch)
# Processing batch 466/762
# Batch 466/762 processed in 11.25 seconds (time per batch)
# Processing batch 467/762
# Batch 467/762 processed in 11.23 seconds (time per batch)
# Processing batch 468/762
# Batch 468/762 processed in 11.14 seconds (time per batch)
# Processing batch 469/762
# Batch 469/762 processed in 12.84 seconds (time per batch)
# Processing batch 470/762
# Batch 470/762 processed in 11.53 seconds (time per batch)
# Processing batch 471/762
# Batch 471/762 processed in 11.39 seconds (time per batch)
# Processing batch 472/762
# Batch 472/762 processed in 11.11 seconds (time per batch)
# Processing batch 473/762
# Batch 473/762 processed in 10.90 seconds (time per batch)
# Processing batch 474/762
# Batch 474/762 processed in 12.16 seconds (time per batch)
# Processing batch 475/762
# Batch 475/762 processed in 10.96 seconds (time per batch)
# Processing batch 476/762
# Batch 476/762 processed in 11.69 seconds (time per batch)
# Processing batch 477/762
# Batch 477/762 processed in 11.32 seconds (time per batch)
# Processing batch 478/762
# Batch 478/762 processed in 11.79 seconds (time per batch)
# Processing batch 479/762
# Batch 479/762 processed in 11.50 seconds (time per batch)
# Processing batch 480/762
# Batch 480/762 processed in 11.65 seconds (time per batch)
# Processing batch 481/762
# Batch 481/762 processed in 11.26 seconds (time per batch)
# Processing batch 482/762
# Batch 482/762 processed in 11.57 seconds (time per batch)
# Processing batch 483/762
# Batch 483/762 processed in 12.05 seconds (time per batch)
# Processing batch 484/762
# Batch 484/762 processed in 11.85 seconds (time per batch)
# Processing batch 485/762
# Batch 485/762 processed in 11.37 seconds (time per batch)
# Processing batch 486/762
# Batch 486/762 processed in 11.53 seconds (time per batch)
# Processing batch 487/762
# Batch 487/762 processed in 11.26 seconds (time per batch)
# Processing batch 488/762
# Batch 488/762 processed in 11.87 seconds (time per batch)
# Processing batch 489/762
# Batch 489/762 processed in 11.22 seconds (time per batch)
# Processing batch 490/762
# Batch 490/762 processed in 12.32 seconds (time per batch)
# Processing batch 491/762
# Batch 491/762 processed in 11.71 seconds (time per batch)
# Processing batch 492/762
# Batch 492/762 processed in 11.19 seconds (time per batch)
# Processing batch 493/762
# Batch 493/762 processed in 11.58 seconds (time per batch)
# Processing batch 494/762
# Batch 494/762 processed in 10.94 seconds (time per batch)
# Processing batch 495/762
# Batch 495/762 processed in 11.51 seconds (time per batch)
# Processing batch 496/762
# Batch 496/762 processed in 11.50 seconds (time per batch)
# Processing batch 497/762
# Batch 497/762 processed in 11.30 seconds (time per batch)
# Processing batch 498/762
# Batch 498/762 processed in 12.12 seconds (time per batch)
# Processing batch 499/762
# Batch 499/762 processed in 10.97 seconds (time per batch)
# Processing batch 500/762
# Batch 500/762 processed in 11.60 seconds (time per batch)
# Processing batch 501/762
# Batch 501/762 processed in 11.02 seconds (time per batch)
# Processing batch 502/762
# Batch 502/762 processed in 11.39 seconds (time per batch)
# Processing batch 503/762
# Batch 503/762 processed in 10.87 seconds (time per batch)
# Processing batch 504/762
# Batch 504/762 processed in 10.96 seconds (time per batch)
# Processing batch 505/762
# Batch 505/762 processed in 10.95 seconds (time per batch)
# Processing batch 506/762
# Batch 506/762 processed in 10.85 seconds (time per batch)
# Processing batch 507/762
# Batch 507/762 processed in 11.39 seconds (time per batch)
# Processing batch 508/762
# Batch 508/762 processed in 11.79 seconds (time per batch)
# Processing batch 509/762
# Batch 509/762 processed in 11.06 seconds (time per batch)
# Processing batch 510/762
# Batch 510/762 processed in 10.94 seconds (time per batch)
# Processing batch 511/762
# Batch 511/762 processed in 11.39 seconds (time per batch)
# Processing batch 512/762
# Batch 512/762 processed in 11.37 seconds (time per batch)
# Processing batch 513/762
# Batch 513/762 processed in 11.10 seconds (time per batch)
# Processing batch 514/762
# Batch 514/762 processed in 10.92 seconds (time per batch)
# Processing batch 515/762
# Batch 515/762 processed in 11.05 seconds (time per batch)
# Processing batch 516/762
# Batch 516/762 processed in 10.89 seconds (time per batch)
# Processing batch 517/762
# Batch 517/762 processed in 11.91 seconds (time per batch)
# Processing batch 518/762
# Batch 518/762 processed in 11.69 seconds (time per batch)
# Processing batch 519/762
# Batch 519/762 processed in 11.71 seconds (time per batch)
# Processing batch 520/762
# Batch 520/762 processed in 11.49 seconds (time per batch)
# Processing batch 521/762
# Batch 521/762 processed in 11.48 seconds (time per batch)
# Processing batch 522/762
# Batch 522/762 processed in 11.77 seconds (time per batch)
# Processing batch 523/762
# Batch 523/762 processed in 11.41 seconds (time per batch)
# Processing batch 524/762
# Batch 524/762 processed in 11.28 seconds (time per batch)
# Processing batch 525/762
# Batch 525/762 processed in 11.49 seconds (time per batch)
# Processing batch 526/762
# Batch 526/762 processed in 10.97 seconds (time per batch)
# Processing batch 527/762
# Batch 527/762 processed in 12.06 seconds (time per batch)
# Processing batch 528/762
# Batch 528/762 processed in 11.51 seconds (time per batch)
# Processing batch 529/762
# Batch 529/762 processed in 11.29 seconds (time per batch)
# Processing batch 530/762
# Batch 530/762 processed in 11.01 seconds (time per batch)
# Processing batch 531/762
# Batch 531/762 processed in 11.04 seconds (time per batch)
# Processing batch 532/762
# Batch 532/762 processed in 12.43 seconds (time per batch)
# Processing batch 533/762
# Batch 533/762 processed in 11.12 seconds (time per batch)
# Processing batch 534/762
# Batch 534/762 processed in 11.04 seconds (time per batch)
# Processing batch 535/762
# Batch 535/762 processed in 10.89 seconds (time per batch)
# Processing batch 536/762
# Batch 536/762 processed in 11.24 seconds (time per batch)
# Processing batch 537/762
# Batch 537/762 processed in 11.02 seconds (time per batch)
# Processing batch 538/762
# Batch 538/762 processed in 10.91 seconds (time per batch)
# Processing batch 539/762
# Batch 539/762 processed in 11.35 seconds (time per batch)
# Processing batch 540/762
# Batch 540/762 processed in 11.47 seconds (time per batch)
# Processing batch 541/762
# Batch 541/762 processed in 11.14 seconds (time per batch)
# Processing batch 542/762
# Batch 542/762 processed in 11.18 seconds (time per batch)
# Processing batch 543/762
# Batch 543/762 processed in 11.27 seconds (time per batch)
# Processing batch 544/762
# Batch 544/762 processed in 11.57 seconds (time per batch)
# Processing batch 545/762
# Batch 545/762 processed in 11.41 seconds (time per batch)
# Processing batch 546/762
# Batch 546/762 processed in 11.79 seconds (time per batch)
# Processing batch 547/762
# Batch 547/762 processed in 10.85 seconds (time per batch)
# Processing batch 548/762
# Batch 548/762 processed in 11.38 seconds (time per batch)
# Processing batch 549/762
# Batch 549/762 processed in 11.16 seconds (time per batch)
# Processing batch 550/762
# Batch 550/762 processed in 11.37 seconds (time per batch)
# Processing batch 551/762
# Batch 551/762 processed in 11.02 seconds (time per batch)
# Processing batch 552/762
# Batch 552/762 processed in 10.74 seconds (time per batch)
# Processing batch 553/762
# Batch 553/762 processed in 11.12 seconds (time per batch)
# Processing batch 554/762
# Batch 554/762 processed in 11.20 seconds (time per batch)
# Processing batch 555/762
# Batch 555/762 processed in 11.48 seconds (time per batch)
# Processing batch 556/762
# Batch 556/762 processed in 11.23 seconds (time per batch)
# Processing batch 557/762
# Batch 557/762 processed in 11.21 seconds (time per batch)
# Processing batch 558/762
# Batch 558/762 processed in 11.19 seconds (time per batch)
# Processing batch 559/762
# Batch 559/762 processed in 11.81 seconds (time per batch)
# Processing batch 560/762
# Batch 560/762 processed in 11.59 seconds (time per batch)
# Processing batch 561/762
# Batch 561/762 processed in 11.48 seconds (time per batch)
# Processing batch 562/762
# Batch 562/762 processed in 11.17 seconds (time per batch)
# Processing batch 563/762
# Batch 563/762 processed in 11.94 seconds (time per batch)
# Processing batch 564/762
# Batch 564/762 processed in 11.36 seconds (time per batch)
# Processing batch 565/762
# Batch 565/762 processed in 11.91 seconds (time per batch)
# Processing batch 566/762
# Batch 566/762 processed in 11.34 seconds (time per batch)
# Processing batch 567/762
# Batch 567/762 processed in 10.81 seconds (time per batch)
# Processing batch 568/762
# ...
# Batch 620/762 processed in 11.52 seconds (time per batch)
# Processing batch 621/762
# Batch 621/762 processed in 11.12 seconds (time per batch)
# Processing batch 622/762
# Batch 622/762 processed in 11.24 seconds (time per batch)
# Processing batch 623/762
# Batch 623/762 processed in 11.25 seconds (time per batch)
# Processing batch 624/762
# Batch 624/762 processed in 11.57 seconds (time per batch)
# Processing batch 625/762
# Batch 625/762 processed in 11.34 seconds (time per batch)
# Processing batch 626/762
# Batch 626/762 processed in 11.18 seconds (time per batch)
# Processing batch 627/762
# Batch 627/762 processed in 11.16 seconds (time per batch)
# Processing batch 628/762
# Batch 628/762 processed in 11.48 seconds (time per batch)
# Processing batch 629/762
# Batch 629/762 processed in 11.35 seconds (time per batch)
# Processing batch 630/762
# Batch 630/762 processed in 11.19 seconds (time per batch)
# Processing batch 631/762
# Batch 631/762 processed in 11.12 seconds (time per batch)
# Processing batch 632/762
# Batch 632/762 processed in 11.64 seconds (time per batch)
# Processing batch 633/762
# Batch 633/762 processed in 11.08 seconds (time per batch)
# Processing batch 634/762
# Batch 634/762 processed in 11.04 seconds (time per batch)
# Processing batch 635/762
# Batch 635/762 processed in 11.27 seconds (time per batch)
# Processing batch 636/762
# Batch 636/762 processed in 11.15 seconds (time per batch)
# Processing batch 637/762
# Batch 637/762 processed in 10.92 seconds (time per batch)
# Processing batch 638/762
# Batch 638/762 processed in 11.55 seconds (time per batch)
# Processing batch 639/762
# Batch 639/762 processed in 11.17 seconds (time per batch)
# Processing batch 640/762
# Batch 640/762 processed in 11.37 seconds (time per batch)
# Processing batch 641/762
# Batch 641/762 processed in 11.70 seconds (time per batch)
# Processing batch 642/762
# Batch 642/762 processed in 11.14 seconds (time per batch)
# Processing batch 643/762
# Batch 643/762 processed in 11.22 seconds (time per batch)
# Processing batch 644/762
# Batch 644/762 processed in 10.85 seconds (time per batch)
# Processing batch 645/762
# Batch 645/762 processed in 11.72 seconds (time per batch)
# Processing batch 646/762
# Batch 646/762 processed in 11.27 seconds (time per batch)
# Processing batch 647/762
# Batch 647/762 processed in 11.18 seconds (time per batch)
# Processing batch 648/762
# Batch 648/762 processed in 11.32 seconds (time per batch)
# Processing batch 649/762
# Batch 649/762 processed in 11.66 seconds (time per batch)
# Processing batch 650/762
# Batch 650/762 processed in 11.04 seconds (time per batch)
# Processing batch 651/762
# Batch 651/762 processed in 11.62 seconds (time per batch)
# Processing batch 652/762
# Batch 652/762 processed in 11.05 seconds (time per batch)
# Processing batch 653/762
# Batch 653/762 processed in 11.33 seconds (time per batch)
# Processing batch 654/762
# Batch 654/762 processed in 10.93 seconds (time per batch)
# Processing batch 655/762
# Batch 655/762 processed in 11.11 seconds (time per batch)
# Processing batch 656/762
# Batch 656/762 processed in 11.57 seconds (time per batch)
# Processing batch 657/762
# Batch 657/762 processed in 11.69 seconds (time per batch)
# Processing batch 658/762
# Batch 658/762 processed in 10.98 seconds (time per batch)
# Processing batch 659/762
# Batch 659/762 processed in 11.56 seconds (time per batch)
# Processing batch 660/762
# Batch 660/762 processed in 11.31 seconds (time per batch)
# Processing batch 661/762
# Batch 661/762 processed in 11.40 seconds (time per batch)
# Processing batch 662/762
# Batch 662/762 processed in 11.26 seconds (time per batch)
# Processing batch 663/762
# Batch 663/762 processed in 11.04 seconds (time per batch)
# Processing batch 664/762
# Batch 664/762 processed in 12.03 seconds (time per batch)
# Processing batch 665/762
# Batch 665/762 processed in 11.01 seconds (time per batch)
# Processing batch 666/762
# Batch 666/762 processed in 11.40 seconds (time per batch)
# Processing batch 667/762
# Batch 667/762 processed in 10.97 seconds (time per batch)
# Processing batch 668/762
# Batch 668/762 processed in 10.86 seconds (time per batch)
# Processing batch 669/762
# Batch 669/762 processed in 11.13 seconds (time per batch)
# Processing batch 670/762
# Batch 670/762 processed in 11.17 seconds (time per batch)
# Processing batch 671/762
# Batch 671/762 processed in 11.49 seconds (time per batch)
# Processing batch 672/762
# Batch 672/762 processed in 11.44 seconds (time per batch)
# Processing batch 673/762
# Batch 673/762 processed in 11.42 seconds (time per batch)
# Processing batch 674/762
# Batch 674/762 processed in 10.93 seconds (time per batch)
# Processing batch 675/762
# Batch 675/762 processed in 10.99 seconds (time per batch)
# Processing batch 676/762
# Batch 676/762 processed in 10.86 seconds (time per batch)
# Processing batch 677/762
# Batch 677/762 processed in 11.61 seconds (time per batch)
# Processing batch 678/762
# Batch 678/762 processed in 11.22 seconds (time per batch)
# Processing batch 679/762
# Batch 679/762 processed in 11.06 seconds (time per batch)
# Processing batch 680/762
# Batch 680/762 processed in 11.05 seconds (time per batch)
# Processing batch 681/762
# Batch 681/762 processed in 12.18 seconds (time per batch)
# Processing batch 682/762
# Batch 682/762 processed in 11.04 seconds (time per batch)
# Processing batch 683/762
# Batch 683/762 processed in 11.01 seconds (time per batch)
# Processing batch 684/762
# Batch 684/762 processed in 11.14 seconds (time per batch)
# Processing batch 685/762
# Batch 685/762 processed in 11.53 seconds (time per batch)
# Processing batch 686/762
# Batch 686/762 processed in 11.00 seconds (time per batch)
# Processing batch 687/762
# Batch 687/762 processed in 11.09 seconds (time per batch)
# Processing batch 688/762
# Batch 688/762 processed in 11.31 seconds (time per batch)
# Processing batch 689/762
# Batch 689/762 processed in 11.67 seconds (time per batch)
# Processing batch 690/762
# Batch 690/762 processed in 10.99 seconds (time per batch)
# Processing batch 691/762
# Batch 691/762 processed in 11.05 seconds (time per batch)
# Processing batch 692/762
# Batch 692/762 processed in 11.52 seconds (time per batch)
# Processing batch 693/762
# Batch 693/762 processed in 11.19 seconds (time per batch)
# Processing batch 694/762
# Batch 694/762 processed in 11.48 seconds (time per batch)
# Processing batch 695/762
# Batch 695/762 processed in 11.19 seconds (time per batch)
# Processing batch 696/762
# Batch 696/762 processed in 10.98 seconds (time per batch)
# Processing batch 697/762
# Batch 697/762 processed in 10.98 seconds (time per batch)
# Processing batch 698/762
# Batch 698/762 processed in 10.97 seconds (time per batch)
# Processing batch 699/762
# Batch 699/762 processed in 11.16 seconds (time per batch)
# Processing batch 700/762
# Batch 700/762 processed in 11.42 seconds (time per batch)
# Processing batch 701/762
# Batch 701/762 processed in 11.26 seconds (time per batch)
# Processing batch 702/762
# Batch 702/762 processed in 11.04 seconds (time per batch)
# Processing batch 703/762
# Batch 703/762 processed in 11.32 seconds (time per batch)
# Processing batch 704/762
# Batch 704/762 processed in 11.63 seconds (time per batch)
# Processing batch 705/762
# Batch 705/762 processed in 11.78 seconds (time per batch)
# Processing batch 706/762
# Batch 706/762 processed in 11.02 seconds (time per batch)
# Processing batch 707/762
# Batch 707/762 processed in 11.35 seconds (time per batch)
# Processing batch 708/762
# Batch 708/762 processed in 10.78 seconds (time per batch)
# Processing batch 709/762
# Batch 709/762 processed in 11.49 seconds (time per batch)
# Processing batch 710/762
# Batch 710/762 processed in 11.09 seconds (time per batch)
# Processing batch 711/762
# Batch 711/762 processed in 11.23 seconds (time per batch)
# Processing batch 712/762
# Batch 712/762 processed in 11.36 seconds (time per batch)
# Processing batch 713/762
# Batch 713/762 processed in 11.82 seconds (time per batch)
# Processing batch 714/762
# Batch 714/762 processed in 11.08 seconds (time per batch)
# Processing batch 715/762
# Batch 715/762 processed in 11.30 seconds (time per batch)
# Processing batch 716/762
# Batch 716/762 processed in 11.23 seconds (time per batch)
# Processing batch 717/762
# Batch 717/762 processed in 10.95 seconds (time per batch)
# Processing batch 718/762
# Batch 718/762 processed in 11.23 seconds (time per batch)
# Processing batch 719/762
# Batch 719/762 processed in 10.88 seconds (time per batch)
# Processing batch 720/762
# Batch 720/762 processed in 11.50 seconds (time per batch)
# Processing batch 721/762
# Batch 721/762 processed in 11.17 seconds (time per batch)
# Processing batch 722/762
# Batch 722/762 processed in 10.99 seconds (time per batch)
# Processing batch 723/762
# Batch 723/762 processed in 11.00 seconds (time per batch)
# Processing batch 724/762
# Batch 724/762 processed in 11.24 seconds (time per batch)
# Processing batch 725/762
# Batch 725/762 processed in 11.56 seconds (time per batch)
# Processing batch 726/762
# Batch 726/762 processed in 10.83 seconds (time per batch)
# Processing batch 727/762
# Batch 727/762 processed in 11.20 seconds (time per batch)
# Processing batch 728/762
# Batch 728/762 processed in 11.07 seconds (time per batch)
# Processing batch 729/762
# Batch 729/762 processed in 10.92 seconds (time per batch)
# Processing batch 730/762
# Batch 730/762 processed in 10.83 seconds (time per batch)
# Processing batch 731/762
# Batch 731/762 processed in 11.33 seconds (time per batch)
# Processing batch 732/762
# Batch 732/762 processed in 11.46 seconds (time per batch)
# Processing batch 733/762
# Batch 733/762 processed in 11.06 seconds (time per batch)
# Processing batch 734/762
# Batch 734/762 processed in 11.39 seconds (time per batch)
# Processing batch 735/762
# Batch 735/762 processed in 11.53 seconds (time per batch)
# Processing batch 736/762
# Batch 736/762 processed in 11.22 seconds (time per batch)
# Processing batch 737/762
# Batch 737/762 processed in 11.12 seconds (time per batch)
# Processing batch 738/762
# Batch 738/762 processed in 11.12 seconds (time per batch)
# Processing batch 739/762
# Batch 739/762 processed in 10.89 seconds (time per batch)
# Processing batch 740/762
# Batch 740/762 processed in 11.61 seconds (time per batch)
# Processing batch 741/762
# Batch 741/762 processed in 11.11 seconds (time per batch)
# Processing batch 742/762
# Batch 742/762 processed in 11.69 seconds (time per batch)
# Processing batch 743/762
# Batch 743/762 processed in 11.16 seconds (time per batch)
# Processing batch 744/762
# Batch 744/762 processed in 10.91 seconds (time per batch)
# Processing batch 745/762
# Batch 745/762 processed in 11.19 seconds (time per batch)
# Processing batch 746/762
# Batch 746/762 processed in 11.27 seconds (time per batch)
# Processing batch 747/762
# Batch 747/762 processed in 11.65 seconds (time per batch)
# Processing batch 748/762
# Batch 748/762 processed in 11.63 seconds (time per batch)
# Processing batch 749/762
# Batch 749/762 processed in 10.90 seconds (time per batch)
# Processing batch 750/762
# Batch 750/762 processed in 11.04 seconds (time per batch)
# Processing batch 751/762
# Batch 751/762 processed in 10.86 seconds (time per batch)
# Processing batch 752/762
# Batch 752/762 processed in 11.91 seconds (time per batch)
# Processing batch 753/762
# Batch 753/762 processed in 11.26 seconds (time per batch)
# Processing batch 754/762
# Batch 754/762 processed in 11.78 seconds (time per batch)
# Processing batch 755/762
# Batch 755/762 processed in 11.54 seconds (time per batch)
# Processing batch 756/762
# Batch 756/762 processed in 11.44 seconds (time per batch)
# Processing batch 757/762
# Batch 757/762 processed in 11.54 seconds (time per batch)
# Processing batch 758/762
# Batch 758/762 processed in 11.13 seconds (time per batch)
# Processing batch 759/762
# Batch 759/762 processed in 11.12 seconds (time per batch)
# Processing batch 760/762
# Batch 760/762 processed in 10.90 seconds (time per batch)
# Processing batch 761/762
# Batch 761/762 processed in 11.75 seconds (time per batch)
# Processing batch 762/762
# Batch 762/762 processed in 2.53 seconds (time per batch)
# Run time statistics:
# Average time per batch: 11.63 seconds
# Total time: 8859.12 seconds
# [14.494762897491455, 12.238248109817505, 12.718295812606812, 12.340023040771484, 14.150691270828247, 15.312124967575073, 12.23889684677124, 11.994160890579224, 12.687604188919067, 11.992461681365967, 11.62628722190857, 12.00227975845337, 11.587055921554565, 12.458730936050415, 12.226502656936646, 11.699437141418457, 11.76954984664917, 11.765899181365967, 12.511668682098389, 12.108157396316528, 12.083950996398926, 12.07710862159729, 11.723773956298828, 12.648953676223755, 12.094949960708618, 12.032662868499756, 11.915976762771606, 12.367775440216064, 12.390163898468018, 12.041603803634644, 12.18039321899414, 12.063546419143677, 12.259061574935913, 12.330687522888184, 11.757135152816772, 12.150958061218262, 11.979798555374146, 12.38212537765503, 12.112359285354614, 12.460808992385864, 11.954328298568726, 12.169734239578247, 11.987027645111084, 11.693525314331055, 12.32793402671814, 12.548107862472534, 12.509001016616821, 11.877949237823486, 12.152778387069702, 11.950023651123047, 12.401584148406982, 12.424379110336304, 12.482125759124756, 11.59503173828125, 11.847053289413452, 11.94695234298706, 12.004581928253174, 12.52996301651001, 12.007678985595703, 11.906437873840332, 12.101128101348877, 12.024429559707642, 12.550801038742065, 11.948373317718506, 11.881476879119873, 12.21561336517334, 11.795307874679565, 12.892606019973755, 12.183416843414307, 11.771162986755371, 11.790894985198975, 12.333019971847534, 12.084164381027222, 12.258158683776855, 11.961242914199829, 12.101896286010742, 11.738565444946289, 12.340374946594238, 11.748327255249023, 11.918644666671753, 12.020575046539307, 12.378714799880981, 12.206525564193726, 15.031464338302612, 11.779314994812012, 12.200342178344727, 12.11199426651001, 12.969532489776611, 12.614717960357666, 13.75798773765564, 12.613381385803223, 12.561798334121704, 12.580701351165771, 12.844696760177612, 12.103119611740112, 12.19018006324768, 13.013914108276367, 12.134003400802612, 12.237413167953491, 11.762406826019287, 12.185092449188232, 12.472688674926758, 11.855452299118042, 12.122597455978394, 11.931063413619995, 11.859812021255493, 12.339652299880981, 12.48941445350647, 12.34535551071167, 12.070394515991211, 12.225071668624878, 12.043487310409546, 12.52321982383728, 12.142517566680908, 11.695901155471802, 12.772496461868286, 12.291982889175415, 12.166078805923462, 11.800806283950806, 11.874765396118164, 12.1766037940979, 12.36859130859375, 12.291041374206543, 11.586145401000977, 11.983546257019043, 11.984384059906006, 13.092941284179688, 11.873136520385742, 11.5324125289917, 13.198480129241943, 11.98500108718872, 13.26901912689209, 12.019114971160889, 12.257538080215454, 11.501967430114746, 11.667718172073364, 13.23407793045044, 12.042451858520508, 11.931167364120483, 11.83287501335144, 12.056761980056763, 12.66300630569458, 12.137168645858765, 12.064577102661133, 12.236161231994629, 11.874841928482056, 12.57244062423706, 12.263388395309448, 11.921052694320679, 12.41571569442749, 12.860617399215698, 12.559695720672607, 12.281367063522339, 11.955926418304443, 11.712439775466919, 12.021029949188232, 12.05168080329895, 12.107157230377197, 11.5587317943573, 12.227471351623535, 12.074105024337769, 12.267374277114868, 11.858338117599487, 12.085130214691162, 12.422726154327393, 12.30068850517273, 12.175037860870361, 11.943497657775879, 12.390472888946533, 12.339060544967651, 13.082722663879395, 12.000678777694702, 12.48433232307434, 11.6311776638031, 11.963398218154907, 12.52097487449646, 11.709758758544922, 11.953638792037964, 11.877176284790039, 12.380115270614624, 13.80410647392273, 11.933331966400146, 11.467816591262817, 11.978854179382324, 11.633247137069702, 12.17370867729187, 11.977821350097656, 11.245193719863892, 12.021118640899658, 12.344686269760132, 11.982934951782227, 11.598908185958862, 11.435402870178223, 11.551498889923096, 11.796655178070068, 11.94718313217163, 11.732447147369385, 11.78749704360962, 12.482565879821777, 12.186088562011719, 11.939658164978027, 11.985516786575317, 1 ...
# Features extracted and saved for model: bert-large

# %%
# features1 = extract_features(dt.FullText, model_name='bert')
# features2 = extract_features(dt.FullText, model_name='gpt2')
# features3 = extract_features(dt.FullText, model_name='roberta')
# features4 = extract_features(dt.FullText, model_name='mt5')
# features5 = extract_features(dt.FullText, model_name='xlnet')
#mt5 - 580 mln parameters
# Out:
# Some weights of the model checkpoint at google/mt5-base were not used when initializing MT5Model: ['lm_head.weight']
# - This IS expected if you are initializing MT5Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing MT5Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Processing batch 1

# %%
features.shape
# Out:
# (20, 768)

# %%
# print(transformers.__version__)
# !pip install --upgrade transformers

# %%
# dir(transformers)
